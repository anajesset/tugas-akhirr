# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd

from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plt.rcParams.update(plt.rcParamsDefault)
plt.rcParams.update({
  "font.size": 16,
  "grid.alpha": 0.25})

# %% [markdown]
# ### Function declarations

# %%
def plot_time_series(x, y, xlabel="Time", ylabel="Value", figsize=(10, 4), 
                     use_date_locator=True, title=None):
  fig, ax = plt.subplots(figsize=figsize)

  ax.plot(x, y)

  if use_date_locator:
    formatter = mdates.DateFormatter("%d/%m/%Y")
    # locator = mdates.YearLocator(base=2)
    locator = mdates.MonthLocator(bymonthday=1, bymonth=range(1, 13, 2))
    ax.xaxis.set_major_formatter(formatter)
    ax.xaxis.set_major_locator(locator)
  

  ax.grid("on")
  ax.set_xlabel(xlabel)
  ax.set_ylabel(ylabel)

  if title is not None:
    ax.set_title(title)

  if use_date_locator:
    for j, label in enumerate(ax.get_xticklabels()):
      label.set_rotation(40)
      label.set_horizontalalignment('right')

  plt.show(fig)

# %%
file_path = "./data/CDB THN 2021-2024.csv"
df_cdb = pd.read_csv(file_path)
df_cdb["Tgl. Mohon"] = pd.to_datetime(df_cdb["Tgl. Mohon"], format="%d/%m/%Y")
df_cdb
# Out:
#      Tgl. Mohon                    Nama                           Alamat  \
# 0    2021-01-02                  MULKAN                  JL AL MAKMUR I
# 1    2021-01-02     HANIE ZULFA NABIELA  JL MT HARYONO PERUM GRAND CITY
# 2    2021-01-02            HASANA PUTRI              JL LETJEND S PARMAN
# 3    2021-01-02             SUSARI HATI           JL MARSMA R ISWAHYUDI
# 4    2021-01-02            ROY KILAPONG                    JL MT HARYONO
# ...         ...                     ...                              ...
# 6852 2024-08-31               RUDI AMSA                  JL PADAT KARYA
# 6853 2024-08-31                 MARIATI            JL. TAMAN BUKIT SARI
# 6854 2024-08-31        JAMES HAROL SELA          JL. LETJEND. S. PARMAN
# 6855 2024-08-31  GOMGOM RAULI SIHOMBING                    PERUM BDS II
# 6856 2024-08-31       NURIANI PATANDEAN                JL BONTO BULAENG
#
#            Kelurahan           Kecamatan     Gender  Tgl. Lahir  \
# 0              DAMAI     BALIKPAPAN KOTA  LAKI-LAKI  18/08/1996
# 1        GRAHA INDAH    BALIKPAPAN UTARA  PEREMPUAN  14/04/2003
# 2        SUMBER REJO   BALIKPAPAN TENGAH  PEREMPUAN  13/02/1997
# 3       SUNGAINANGKA  BALIKPAPAN SELATAN  PEREMPUAN  16/11/1982
# 4      DAMAI BAHAGIA  BALIKPAPAN SELATAN  LAKI-LAKI  17/01/1976
# ...              ...                 ...        ...         ...
# 6852         MANGGAR    BALIKPAPAN TIMUR  LAKI-LAKI  06/11/2004
# 6853     GRAHA INDAH    BALIKPAPAN UTARA  PEREMPUAN  21/03/1978
# 6854  GUNUNGSARI ULU   BALIKPAPAN TENGAH  LAKI-LAKI  19/01/1961
# 6855    SUNGAINANGKA  BALIKPAPAN SELATAN  PEREMPUAN  30/04/1980
# 6856     SUMBER REJO   BALIKPAPAN TENGAH  PEREMPUAN  08/04/1993
#
#                      Pekerjaan                          Pengeluaran  \
# 0              Wiraswasta-Jasa  Rp. 1.750.001,- s/d Rp. 2.500.000,-
# 1          Pegawai Swasta-Jasa                      < Rp. 900.000,-
# 2     Pegawai Swasta-Pertanian    Rp. 900.001,- s/d Rp. 1.250.000,-
# 3      Pegawai Swasta-Industri  Rp. 4.000.001,- s/d Rp. 6.000.000,-
# 4          Pegawai Swasta-Jasa  Rp. 2.500.001,- s/d Rp. 4.000.000,-
# ...                        ...                                  ...
# 6852       Pegawai Swasta-Jasa    Rp. 900.001,- s/d Rp. 1.250.000,-
# 6853       Pegawai Swasta-Jasa  Rp. 1.750.001,- s/d Rp. 2.500.000,-
# 6854       Pegawai Swasta-Jasa  Rp. 1.750.001,- s/d Rp. 2.500.000,-
# 6855          IBU RUMAH TANGGA  Rp. 1.250.001,- s/d Rp. 1.750.000,-
# 6856          IBU RUMAH TANGGA    Rp. 900.001,- s/d Rp. 1.250.000,-
#
#            Pendidikan Varian Plus
# 0            SLTP/SMP         LD0
# 1     AKADEMI/DIPLOMA         LP0
# 2             SARJANA         LPA
# 3            SLTA/SMU         LP0
# 4            SLTA/SMU         LPA
# ...               ...         ...
# 6852         SLTA/SMU         MM0
# 6853         SLTA/SMU         MM0
# 6854          SARJANA         LP3
# 6855         SLTA/SMU         ML0
# 6856         SLTA/SMU         LW1
#
# [6857 rows x 11 columns]

# %% [markdown]
# Adding new column of first initial of "Varian Plus"

# %%
df_cdb_with_initial = df_cdb.copy()
df_cdb_with_initial["initial Varian Plus"] = df_cdb_with_initial["Varian Plus"].apply(lambda x: x[0])
df_cdb_with_initial
# Out:
#      Tgl. Mohon                    Nama                           Alamat  \
# 0    2021-01-02                  MULKAN                  JL AL MAKMUR I
# 1    2021-01-02     HANIE ZULFA NABIELA  JL MT HARYONO PERUM GRAND CITY
# 2    2021-01-02            HASANA PUTRI              JL LETJEND S PARMAN
# 3    2021-01-02             SUSARI HATI           JL MARSMA R ISWAHYUDI
# 4    2021-01-02            ROY KILAPONG                    JL MT HARYONO
# ...         ...                     ...                              ...
# 6852 2024-08-31               RUDI AMSA                  JL PADAT KARYA
# 6853 2024-08-31                 MARIATI            JL. TAMAN BUKIT SARI
# 6854 2024-08-31        JAMES HAROL SELA          JL. LETJEND. S. PARMAN
# 6855 2024-08-31  GOMGOM RAULI SIHOMBING                    PERUM BDS II
# 6856 2024-08-31       NURIANI PATANDEAN                JL BONTO BULAENG
#
#            Kelurahan           Kecamatan     Gender  Tgl. Lahir  \
# 0              DAMAI     BALIKPAPAN KOTA  LAKI-LAKI  18/08/1996
# 1        GRAHA INDAH    BALIKPAPAN UTARA  PEREMPUAN  14/04/2003
# 2        SUMBER REJO   BALIKPAPAN TENGAH  PEREMPUAN  13/02/1997
# 3       SUNGAINANGKA  BALIKPAPAN SELATAN  PEREMPUAN  16/11/1982
# 4      DAMAI BAHAGIA  BALIKPAPAN SELATAN  LAKI-LAKI  17/01/1976
# ...              ...                 ...        ...         ...
# 6852         MANGGAR    BALIKPAPAN TIMUR  LAKI-LAKI  06/11/2004
# 6853     GRAHA INDAH    BALIKPAPAN UTARA  PEREMPUAN  21/03/1978
# 6854  GUNUNGSARI ULU   BALIKPAPAN TENGAH  LAKI-LAKI  19/01/1961
# 6855    SUNGAINANGKA  BALIKPAPAN SELATAN  PEREMPUAN  30/04/1980
# 6856     SUMBER REJO   BALIKPAPAN TENGAH  PEREMPUAN  08/04/1993
#
#                      Pekerjaan                          Pengeluaran  \
# 0              Wiraswasta-Jasa  Rp. 1.750.001,- s/d Rp. 2.500.000,-
# 1          Pegawai Swasta-Jasa                      < Rp. 900.000,-
# 2     Pegawai Swasta-Pertanian    Rp. 900.001,- s/d Rp. 1.250.000,-
# 3      Pegawai Swasta-Industri  Rp. 4.000.001,- s/d Rp. 6.000.000,-
# 4          Pegawai Swasta-Jasa  Rp. 2.500.001,- s/d Rp. 4.000.000,-
# ...                        ...                                  ...
# 6852       Pegawai Swasta-Jasa    Rp. 900.001,- s/d Rp. 1.250.000,-
# 6853       Pegawai Swasta-Jasa  Rp. 1.750.001,- s/d Rp. 2.500.000,-
# 6854       Pegawai Swasta-Jasa  Rp. 1.750.001,- s/d Rp. 2.500.000,-
# 6855          IBU RUMAH TANGGA  Rp. 1.250.001,- s/d Rp. 1.750.000,-
# 6856          IBU RUMAH TANGGA    Rp. 900.001,- s/d Rp. 1.250.000,-
#
#            Pendidikan Varian Plus initial Varian Plus
# 0            SLTP/SMP         LD0                   L
# 1     AKADEMI/DIPLOMA         LP0                   L
# 2             SARJANA         LPA                   L
# 3            SLTA/SMU         LP0                   L
# 4            SLTA/SMU         LPA                   L
# ...               ...         ...                 ...
# 6852         SLTA/SMU         MM0                   M
# 6853         SLTA/SMU         MM0                   M
# 6854          SARJANA         LP3                   L
# 6855         SLTA/SMU         ML0                   M
# 6856         SLTA/SMU         LW1                   L
#
# [6857 rows x 12 columns]

# %% [markdown]
# Jenis varian

# %%
varian_plus_unique = df_cdb["Varian Plus"].unique()
varian_plus_unique
# Out:
# array(['LD0', 'LP0', 'LPA', 'ES5', 'LNA', 'ES4', 'LK0', 'LJ0', 'HZ3',
#        'HWC', 'LN0', 'GB3', 'EXF', 'HDN', 'LH0', 'LKA', 'HS2', 'LGC',
#        'HT2', 'HWD', 'EW2', 'GF4', 'HW4', 'HY3', 'HS1', 'LE1', 'HT1',
#        'JM0', 'LD2', 'HDP', 'EWE', 'LS0', 'LR0', 'HJK', 'EG1', 'ES3',
#        'HD7', 'LF1', 'HJ9', 'LFE', 'EYE', 'GD3', 'EWD', 'JMB', 'HZ4',
#        'LG1', 'HY4', 'JN0', 'HZA', 'JMC', 'LH1', 'LKC', 'LJ1', 'JS0',
#        'LK1', 'ESF', 'ESE', 'EH2', 'LPB', 'LNE', 'LP1', 'LN1', 'JXA',
#        'JX0', 'LV0', 'LW0', 'JMA', 'LVA', 'GD4', 'LWA', 'GB4', 'ES6',
#        'LZ0', 'LY0', 'GF5', 'JR0', 'JND', 'MA0', 'MB0', 'MDA', 'MC0',
#        'MD0', 'LP2', 'LN2', 'LPC', 'LNG', 'EG2', 'LR1', 'LS1', 'JMG',
#        'LK2', 'LJ2', 'LH2', 'JMH', 'JM1', 'JMJ', 'LY1', 'LZ1', 'JNT',
#        'LVE', 'LV1', 'LW1', 'LN3', 'LPD', 'LP3', 'LNJ', 'MG0', 'MF0',
#        'JN1', 'MC1', 'MD1', 'ML0', 'MM0', 'MJ0', 'MK0'], dtype=object)

# %%
len(varian_plus_unique)
# Out:
# 115

# %% [markdown]
# Create a histogram of Varian Plus

# %%
df_cdb_varian_plus = df_cdb[["Varian Plus"]].copy()
df_cdb_varian_plus["count"] = 1.
df_cdb_varian_plus = df_cdb_varian_plus.groupby("Varian Plus").agg("count").reset_index()
df_cdb_varian_plus
# Out:
#     Varian Plus  count
# 0           EG1      1
# 1           EG2     22
# 2           EH2    136
# 3           ES3     10
# 4           ES4     76
# ..          ...    ...
# 110         MG0     14
# 111         MJ0     27
# 112         MK0     14
# 113         ML0     31
# 114         MM0     31
#
# [115 rows x 2 columns]

# %%
step = 20   # number of category in one subplot

fig, axes = plt.subplots(nrows=len(varian_plus_unique) // step + 1, ncols=1, figsize=(6, 12))

for idx, ax in enumerate(axes):
  idx_start = idx*step
  idx_end = idx*step + step
  
  # because pandas includes right endpoint, we must subtract by one
  x_data = df_cdb_varian_plus.loc[idx_start:idx_end-1, "Varian Plus"]
  y_data = df_cdb_varian_plus.loc[idx_start:idx_end-1, "count"]
  axes[idx].bar(x_data, y_data)

  axes[idx].set_xticks(np.arange(len(varian_plus_unique[idx_start:idx_end])))
  axes[idx].set_xticklabels(x_data, rotation=45, fontsize=8)

  axes[idx].set_ylim([0, 400])

plt.subplots_adjust(hspace=0.3)
plt.show(fig)

# %% [markdown]
# Take Varian Plus "LK2"

# %%
df_LK2 = df_cdb[df_cdb["Varian Plus"] == "LK2"].copy()
df_LK2
# Out:
#      Tgl. Mohon                        Nama  \
# 3410 2023-02-17               ZAHROTUN NISA
# 3437 2023-02-21                      HADIRI
# 3447 2023-02-22               JOKO PURWANTO
# 3456 2023-02-24                  EEN ROSANA
# 3467 2023-02-25             RAUDATUL JANNAH
# ...         ...                         ...
# 6398 2024-06-19    MOHAMMAD RIZAL KURNIAWAN
# 6419 2024-06-25                      RANITI
# 6421 2024-06-25  CHRISTIYANTO PURNOMO BROTO
# 6424 2024-06-26         NOOR CAHAYA NINGRUM
# 6473 2024-07-04            CRISTINA NOVIA R
#
#                                    Alamat        Kelurahan  \
# 3410             JL.MARSMA R. ISWAHYUDI       SUNGAINANGKA
# 3437                JL MASJID AR RAUDHAH     DAMAI BAHAGIA
# 3447                 GRIYA PRIMA LESTARI       GRAHA INDAH
# 3456                            PERUMNAS        BATU AMPAR
# 3467                       JL. WONOREJO 3  GUNUNGSAMARINDA
# ...                                   ...              ...
# 6398                   JL. MARKONI DALAM             DAMAI
# 6419  JL. ASRAMA BUKIT GG 45 GUNUNG SATU       MARGO MULYO
# 6421                       JL MT HARYONO             DAMAI
# 6424                   JL TELAGA SARI II       TELAGA SARI
# 6473                     JL BARU LEMBUKU    SEPINGGAN BARU
#
#                Kecamatan     Gender  Tgl. Lahir                    Pekerjaan  \
# 3410  BALIKPAPAN SELATAN  PEREMPUAN  12/04/1976             IBU RUMAH TANGGA
# 3437  BALIKPAPAN SELATAN  LAKI-LAKI  25/03/1973       Wiraswasta-Perdagangan
# 3447    BALIKPAPAN UTARA  LAKI-LAKI  08/03/1979               PEGAWAI NEGERI
# 3456    BALIKPAPAN UTARA  PEREMPUAN  01/09/1998   Pegawai Swasta-Perdagangan
# 3467    BALIKPAPAN UTARA  PEREMPUAN  14/07/1984  Pegawai Swasta-Pertambangan
# ...                  ...        ...         ...                          ...
# 6398     BALIKPAPAN KOTA  LAKI-LAKI  12/06/1996   Pegawai Swasta-Perdagangan
# 6419    BALIKPAPAN BARAT  PEREMPUAN  11/10/1987       Wiraswasta-Perdagangan
# 6421     BALIKPAPAN KOTA  LAKI-LAKI  26/01/1978              Wiraswasta-Jasa
# 6424     BALIKPAPAN KOTA  PEREMPUAN  28/03/2004            MAHASISWA/PELAJAR
# 6473  BALIKPAPAN SELATAN  PEREMPUAN  20/11/1989             IBU RUMAH TANGGA
#
#                               Pengeluaran Pendidikan Varian Plus
# 3410  Rp. 2.500.001,- s/d Rp. 4.000.000,-   SLTA/SMU         LK2
# 3437  Rp. 1.750.001,- s/d Rp. 2.500.000,-   SLTA/SMU         LK2
# 3447  Rp. 1.750.001,- s/d Rp. 2.500.000,-   SLTA/SMU         LK2
# 3456  Rp. 1.750.001,- s/d Rp. 2.500.000,-   SLTP/SMP         LK2
# 3467  Rp. 1.250.001,- s/d Rp. 1.750.000,-    SARJANA         LK2
# ...                                   ...        ...         ...
# 6398  Rp. 1.750.001,- s/d Rp. 2.500.000,-   SLTA/SMU         LK2
# 6419  Rp. 1.750.001,- s/d Rp. 2.500.000,-         SD         LK2
# 6421  Rp. 1.250.001,- s/d Rp. 1.750.000,-   SLTA/SMU         LK2
# 6424    Rp. 900.001,- s/d Rp. 1.250.000,-   SLTA/SMU         LK2
# 6473  Rp. 1.250.001,- s/d Rp. 1.750.000,-   SLTA/SMU         LK2
#
# [385 rows x 11 columns]

# %%
df_LK2_count = df_LK2[["Tgl. Mohon"]].copy()
df_LK2_count["count"] = 1.
df_LK2_count = df_LK2_count.groupby("Tgl. Mohon").agg("count").reset_index()
df_LK2_count
# Out:
#     Tgl. Mohon  count
# 0   2023-02-17      1
# 1   2023-02-21      1
# 2   2023-02-22      1
# 3   2023-02-24      1
# 4   2023-02-25      2
# ..         ...    ...
# 220 2024-06-14      2
# 221 2024-06-19      1
# 222 2024-06-25      2
# 223 2024-06-26      1
# 224 2024-07-04      1
#
# [225 rows x 2 columns]

# %%
df_LK2_count["Tgl. Mohon"][0]
# Out:
# Timestamp('2023-02-17 00:00:00')

# %%
fig, ax = plt.subplots(figsize=(8, 3))

ax.plot(df_LK2_count["Tgl. Mohon"], df_LK2_count["count"], linestyle="None",
        marker=".")

formatter = mdates.DateFormatter("%d/%m/%Y")
# locator = mdates.YearLocator(base=2)
locator = mdates.MonthLocator(bymonthday=1, bymonth=range(1, 13, 2))
ax.xaxis.set_major_formatter(formatter)
ax.xaxis.set_major_locator(locator)

ax.grid("on")
ax.set_xlabel("Tgl. Mohon")
ax.set_ylabel("Jumlah permohonan")

ax.set_title("df_LK_count")

for j, label in enumerate(ax.get_xticklabels()):
  label.set_rotation(40)
  label.set_fontsize(8)
  label.set_horizontalalignment('right')

plt.show(fig)

# %% [markdown]
# Jumlah initial Varian PLus

# %%
initial_varian_plus_unique = df_cdb_with_initial["initial Varian Plus"].unique()
initial_varian_plus_unique
# Out:
# array(['L', 'E', 'H', 'G', 'J', 'M'], dtype=object)

# %%
len(initial_varian_plus_unique)
# Out:
# 6

# %% [markdown]
# Histogram diagram of initial Varian Plus

# %%
df_cdb_initial_varian_plus = df_cdb_with_initial[["initial Varian Plus"]].copy()
df_cdb_initial_varian_plus["count"] = 1.
df_cdb_initial_varian_plus = df_cdb_initial_varian_plus.groupby("initial Varian Plus").agg("count").reset_index()
df_cdb_initial_varian_plus
# Out:
#   initial Varian Plus  count
# 0                   E    426
# 1                   G    237
# 2                   H    447
# 3                   J     84
# 4                   L   5130
# 5                   M    533

# %%
fig, ax = plt.subplots(figsize=(10, 6))

x_data = df_cdb_initial_varian_plus["initial Varian Plus"]
y_data = df_cdb_initial_varian_plus["count"]

ax.bar(x_data, y_data)

ax.set_xticks(np.arange(len(x_data)))
ax.set_xticklabels(x_data, rotation=45, fontsize=12)
ax.set_ylabel("Count")
ax.set_title("Histogram diagram of initial Varian Plus")

ax.set_ylim([0, df_cdb_initial_varian_plus["count"].max() + 100])

plt.grid(True, axis='y', linestyle='--', alpha=0.7)
plt.show(fig)

# %% [markdown]
# ### Time series for each category

# %%
df_E = df_cdb_with_initial[df_cdb_with_initial["initial Varian Plus"] == "E"].copy()
df_E_count = df_E[["Tgl. Mohon"]].copy()
df_E_count["count"] = 1.
df_E_count = df_E_count.groupby("Tgl. Mohon").agg("count").reset_index()
df_E_count["cumulative_sum"] = df_E_count["count"].cumsum()

# %%
fig, ax = plt.subplots(figsize=(8, 3))

ax.plot(df_E_count["Tgl. Mohon"], df_E_count["count"], 
        linestyle="-", marker=".")

formatter = mdates.DateFormatter("%d/%m/%Y")
# locator = mdates.YearLocator(base=2)
locator = mdates.MonthLocator(bymonthday=1, bymonth=range(1, 13, 2))
ax.xaxis.set_major_formatter(formatter)
ax.xaxis.set_major_locator(locator)

ax.grid("on")
ax.set_xlabel("Tgl. Mohon")
ax.set_ylabel("Jumlah permohonan")

ax.set_title("df_E_count")

for j, label in enumerate(ax.get_xticklabels()):
  label.set_rotation(40)
  label.set_fontsize(8)
  label.set_horizontalalignment('right')

plt.show(fig)

# %%
adfuller(df_E_count["count"])
# Out:
# (-10.786407197274206,
#  2.1885322414810585e-19,
#  0,
#  174,
#  {'1%': -3.4685016947910636,
#   '5%': -2.8782983668563396,
#   '10%': -2.57570415906989},
#  911.4443416265717)

# %%
plot_acf(df_E_count["count"]);

# %%
plot_pacf(df_E_count["count"]);

# %% [markdown]
# ### Plot kumulatif

# %% [markdown]
# Take initial varian plus "E"

# %%
df_E = df_cdb_with_initial[df_cdb_with_initial["initial Varian Plus"] == "E"].copy()
df_E
# Out:
#      Tgl. Mohon                           Nama  \
# 5    2021-01-04               DEVRYNALDO RIZAL
# 7    2021-01-04                     SUPARYANTO
# 14   2021-01-06                        MULYADI
# 15   2021-01-06              MUHAMMAD FADILLAH
# 18   2021-01-06                 ANDI WIJAYANTO
# ...         ...                            ...
# 6459 2024-06-30     PT KEMILAU INDAH NUSANTARA
# 6523 2024-07-12     PT KEMILAU INDAH NUSANTARA
# 6833 2024-08-29     PT KEMILAU INDAH NUSANTARA
# 6841 2024-08-31                  LINUS HARIMIN
# 6842 2024-08-31  GEREJA KATOLIK SANTO MARTINUS
#
#                                                  Alamat       Kelurahan  \
# 5                                        JL JEND A YANI     KARANG JATI
# 7                   JL KESATRIA PERUM NUSANTARA LESTARI     GRAHA INDAH
# 14                                  JL SYARIFUDIN YOES    GUNUNGBAHAGIA
# 15                                    JL AL MAKMUR III            DAMAI
# 18                                  JL SUGENG RAWUH II        SEPINGGAN
# ...                                                 ...             ...
# 6459                JL. POROS SANGATTA-BENGALON KM. 32   MUARA BENGALON
# 6523  JL POROS SANGATTA-BENGALON KM 32 SIMPANG RAWA ...  MUARA BENGALON
# 6833  JL POROS SANGATTA-BENGGALON KM 32 SIMPANG RAWA...  MUARA BENGALON
# 6841                               JL BATU RATNA KM 11     KARANG JOANG
# 6842                        KOMPLEK AURI JL MULAWARMAN        SEPINGGAN
#
#                Kecamatan     Gender  Tgl. Lahir                Pekerjaan  \
# 5      BALIKPAPAN TENGAH  LAKI-LAKI  18/12/1978      Pegawai Swasta-Jasa
# 7       BALIKPAPAN UTARA  LAKI-LAKI  27/08/1976                      NaN
# 14    BALIKPAPAN SELATAN  LAKI-LAKI  23/12/1974    Wiraswasta-Konstruksi
# 15       BALIKPAPAN KOTA  LAKI-LAKI  07/12/1997        MAHASISWA/PELAJAR
# 18    BALIKPAPAN SELATAN  LAKI-LAKI  06/07/1995          Wiraswasta-Jasa
# ...                  ...        ...         ...                      ...
# 6459            BENGALON  LAKI-LAKI  30/06/1985      Pegawai Swasta-Jasa
# 6523            BENGALON        NaN  18/11/2000  Wiraswasta-Pertambangan
# 6833            BENGALON        NaN  27/08/1992                      NaN
# 6841    BALIKPAPAN UTARA  LAKI-LAKI  23/09/1973      Pegawai Swasta-Jasa
# 6842  BALIKPAPAN SELATAN  LAKI-LAKI  31/08/1981          Wiraswasta-Jasa
#
#                               Pengeluaran Pendidikan Varian Plus  \
# 5                       > Rp. 6.000.000,-    SARJANA         ES5
# 7                                     NaN        NaN         ES4
# 14                      > Rp. 6.000.000,-   SLTA/SMU         ES4
# 15                        < Rp. 900.000,-   SLTP/SMP         ES4
# 18    Rp. 1.250.001,- s/d Rp. 1.750.000,-   SLTA/SMU         ES5
# ...                                   ...        ...         ...
# 6459  Rp. 1.750.001,- s/d Rp. 2.500.000,-   SLTA/SMU         EG2
# 6523                                  NaN        NaN         EG2
# 6833                                  NaN        NaN         EG2
# 6841  Rp. 1.250.001,- s/d Rp. 1.750.000,-   SLTA/SMU         ESF
# 6842                    > Rp. 6.000.000,-   SLTA/SMU         EH2
#
#      initial Varian Plus
# 5                      E
# 7                      E
# 14                     E
# 15                     E
# 18                     E
# ...                  ...
# 6459                   E
# 6523                   E
# 6833                   E
# 6841                   E
# 6842                   E
#
# [426 rows x 12 columns]

# %% [markdown]
# Plot data initial varian plus "E"

# %%
df_E_count = df_E[["Tgl. Mohon"]].copy()
df_E_count["count"] = 1.
df_E_count = df_E_count.groupby("Tgl. Mohon").agg("count").reset_index()
df_E_count["cumulative_sum"] = df_E_count["count"].cumsum()
df_E_count
# Out:
#     Tgl. Mohon  count  cumulative_sum
# 0   2021-01-04      2               2
# 1   2021-01-06      3               5
# 2   2021-01-07      1               6
# 3   2021-01-14      1               7
# 4   2021-01-21      1               8
# ..         ...    ...             ...
# 170 2024-06-05      1             421
# 171 2024-06-30      1             422
# 172 2024-07-12      1             423
# 173 2024-08-29      1             424
# 174 2024-08-31      2             426
#
# [175 rows x 3 columns]

# %%
fig, ax = plt.subplots(figsize=(8, 3))

ax.plot(df_E_count["Tgl. Mohon"], df_E_count["cumulative_sum"], 
        linestyle="-", marker=".")

formatter = mdates.DateFormatter("%d/%m/%Y")
# locator = mdates.YearLocator(base=2)
locator = mdates.MonthLocator(bymonthday=1, bymonth=range(1, 13, 2))
ax.xaxis.set_major_formatter(formatter)
ax.xaxis.set_major_locator(locator)

ax.grid("on")
ax.set_xlabel("Tgl. Mohon")
ax.set_ylabel("Jumlah permohonan")

ax.set_title("df_E_count")

for j, label in enumerate(ax.get_xticklabels()):
  label.set_rotation(40)
  label.set_fontsize(8)
  label.set_horizontalalignment('right')

plt.show(fig)

# %%
adfuller(df_E_count["cumulative_sum"])
# Out:
# (-0.6744342542596905,
#  0.8532609816368074,
#  1,
#  173,
#  {'1%': -3.4687256239864017,
#   '5%': -2.8783961376954363,
#   '10%': -2.57575634100705},
#  913.1426922275209)

# %%
plot_acf(df_E_count["cumulative_sum"]);

# %%
plot_pacf(df_E_count["cumulative_sum"]);

# %% [markdown]
# Take initial varian plus "G"

# %%
df_G = df_cdb_with_initial[df_cdb_with_initial["initial Varian Plus"] == "G"].copy()
df_G
# Out:
#      Tgl. Mohon                         Nama                        Alamat  \
# 22   2021-01-07                       SUMINI                  BABULU DARAT
# 99   2021-01-27                         BUDI               JL PERUM POLDA
# 102  2021-01-28             SAIPUL HOLIS, SE          JL SYARIFUDDIN YOES
# 172  2021-02-22                       SULATI             JL BUKIT PELAJAR
# 288  2021-03-23                      SARINAH                    BULUMINUNG
# ...         ...                          ...                           ...
# 6780 2024-08-21   PT JAYACOM PERSADA MANDIRI                JL MT HARYONO
# 6790 2024-08-22  PT. ARKANANTA APTA PRATISTA                JL MT HARYONO
# 6794 2024-08-23                    AGUSWANTO                   JL.SULAWESI
# 6803 2024-08-24                 HENDRA TAMBA  JL KOLONEL SYARIFUDDIN YOES
# 6825 2024-08-29               BUDIMAN DJAPAR                 JL SUKA ASRI
#
#            Kelurahan           Kecamatan     Gender  Tgl. Lahir  \
# 22      BABULU DARAT              BABULU  PEREMPUAN  07/12/1978
# 99       GRAHA INDAH    BALIKPAPAN UTARA  LAKI-LAKI  01/02/1974
# 102   SEPINGGAN BARU  BALIKPAPAN SELATAN  LAKI-LAKI  18/10/1969
# 172      BARU TENGAH    BALIKPAPAN BARAT  PEREMPUAN  27/02/1972
# 288       BULUMINUNG             PENAJAM  PEREMPUAN  01/12/1980
# ...              ...                 ...        ...         ...
# 6780  GUNUNG BAHAGIA  BALIKPAPAN SELATAN  LAKI-LAKI  01/01/2003
# 6790     GRAHA INDAH    BALIKPAPAN UTARA  LAKI-LAKI  22/08/2006
# 6794     KARANG REJO   BALIKPAPAN TENGAH  LAKI-LAKI  08/07/1972
# 6803  SEPINGGAN BARU  BALIKPAPAN SELATAN  LAKI-LAKI  05/01/1990
# 6825     TELAGA SARI     BALIKPAPAN KOTA  LAKI-LAKI  01/05/1981
#
#                      Pekerjaan                          Pengeluaran  \
# 22      Wiraswasta-Perdagangan    Rp. 900.001,- s/d Rp. 1.250.000,-
# 99                   LAIN-LAIN    Rp. 900.001,- s/d Rp. 1.250.000,-
# 102        Pegawai Swasta-Jasa  Rp. 4.000.001,- s/d Rp. 6.000.000,-
# 172     Wiraswasta-Perdagangan    Rp. 900.001,- s/d Rp. 1.250.000,-
# 288   Pegawai Swasta-Pertanian  Rp. 1.750.001,- s/d Rp. 2.500.000,-
# ...                        ...                                  ...
# 6780           Wiraswasta-Jasa                    > Rp. 6.000.000,-
# 6790           Wiraswasta-Jasa                    > Rp. 6.000.000,-
# 6794       Pegawai Swasta-Jasa                    > Rp. 6.000.000,-
# 6803         MAHASISWA/PELAJAR    Rp. 900.001,- s/d Rp. 1.250.000,-
# 6825           Wiraswasta-Jasa  Rp. 1.250.001,- s/d Rp. 1.750.000,-
#
#      Pendidikan Varian Plus initial Varian Plus
# 22     SLTA/SMU         GB3                   G
# 99     SLTA/SMU         GF4                   G
# 102     SARJANA         GF4                   G
# 172    SLTA/SMU         GB3                   G
# 288    SLTP/SMP         GF4                   G
# ...         ...         ...                 ...
# 6780   SLTA/SMU         GD4                   G
# 6790   SLTA/SMU         GD4                   G
# 6794   SLTA/SMU         GF5                   G
# 6803   SLTA/SMU         GD4                   G
# 6825   SLTA/SMU         GD4                   G
#
# [237 rows x 12 columns]

# %%
df_G_count = df_G[["Tgl. Mohon"]].copy()
df_G_count["count"] = 1.
df_G_count = df_G_count.groupby("Tgl. Mohon").agg("count").reset_index()
df_G_count["cumulative_sum"] = df_G_count["count"].cumsum()
df_G_count
# Out:
#     Tgl. Mohon  count  cumulative_sum
# 0   2021-01-07      1               1
# 1   2021-01-27      1               2
# 2   2021-01-28      1               3
# 3   2021-02-22      1               4
# 4   2021-03-23      1               5
# ..         ...    ...             ...
# 171 2024-08-21      1             233
# 172 2024-08-22      1             234
# 173 2024-08-23      1             235
# 174 2024-08-24      1             236
# 175 2024-08-29      1             237
#
# [176 rows x 3 columns]

# %%
fig, ax = plt.subplots(figsize=(8, 3))

ax.plot(df_G_count["Tgl. Mohon"], df_G_count["cumulative_sum"], 
        linestyle="-", marker=".")

formatter = mdates.DateFormatter("%d/%m/%Y")
# locator = mdates.YearLocator(base=2)
locator = mdates.MonthLocator(bymonthday=1, bymonth=range(1, 13, 2))
ax.xaxis.set_major_formatter(formatter)
ax.xaxis.set_major_locator(locator)

ax.grid("on")
ax.set_xlabel("Tgl. Mohon")
ax.set_ylabel("Jumlah permohonan")

ax.set_title("df_G_count")

for j, label in enumerate(ax.get_xticklabels()):
  label.set_rotation(40)
  label.set_fontsize(8)
  label.set_horizontalalignment('right')

plt.show(fig)

# %% [markdown]
# Take initial varian plus "H"

# %%
df_H = df_cdb_with_initial[df_cdb_with_initial["initial Varian Plus"] == "H"].copy()
df_H
# Out:
#      Tgl. Mohon                       Nama                             Alamat  \
# 12   2021-01-05              JULI HARJANTO                           JL BLORA
# 13   2021-01-06  DHINA R. AGUSTIANA DA, SE              JL MASJID AR RAUDAH I
# 24   2021-01-07       AHMAD HABIBI HARAHAP                  JL DAKSA TIMUR I
# 31   2021-01-07      GALIH PUTRO WICAKSONO  JL JEND SUDIRMAN ASPOL STAL KUDA
# 37   2021-01-09          VELIANA FEBRIANTI                 JL GUNUNG GEMBIRA
# ...         ...                        ...                                ...
# 5956 2024-04-06            ERNIE DIANA NUR                     JL. SIDOMULYO
# 6330 2024-06-06                       ERNI    JL. WOLTET MONGINSIDI GG. MACAN
# 6351 2024-06-10                   ZULFIKAR                      JL TELINDUNG
# 6501 2024-07-08                      JOSUA               JL JENDRAL SUDIRMAN
# 6674 2024-08-05            INOSENSIUS LUSI          JL KAKATUA 2 PERUM BDS 2
#
#            Kelurahan           Kecamatan     Gender  Tgl. Lahir  \
# 12    KLANDASAN ILIR     BALIKPAPAN KOTA  LAKI-LAKI  18/07/1977
# 13    GUNUNG BAHAGIA  BALIKPAPAN SELATAN  PEREMPUAN  13/08/1974
# 24         SEPINGGAN  BALIKPAPAN SELATAN  LAKI-LAKI  30/04/1995
# 31     DAMAI BAHAGIA  BALIKPAPAN SELATAN  LAKI-LAKI  26/05/1993
# 37         BARU ILIR    BALIKPAPAN BARAT  PEREMPUAN  25/02/1997
# ...              ...                 ...        ...         ...
# 5956     MARGO MULYO    BALIKPAPAN BARAT  PEREMPUAN  14/08/1977
# 6330        BARU ULU    BALIKPAPAN BARAT  PEREMPUAN  07/07/1977
# 6351      BATU AMPAR    BALIKPAPAN UTARA  LAKI-LAKI  07/02/1988
# 6501           DAMAI     BALIKPAPAN KOTA  LAKI-LAKI  22/07/2000
# 6674    SUNGAINANGKA  BALIKPAPAN SELATAN  LAKI-LAKI  06/03/2002
#
#                        Pekerjaan                          Pengeluaran  \
# 12           Pegawai Swasta-Jasa                      < Rp. 900.000,-
# 13              IBU RUMAH TANGGA  Rp. 2.500.001,- s/d Rp. 4.000.000,-
# 24           Pegawai Swasta-Jasa  Rp. 1.750.001,- s/d Rp. 2.500.000,-
# 31                     TNI/POLRI                      < Rp. 900.000,-
# 37    Pegawai Swasta-Perdagangan                      < Rp. 900.000,-
# ...                          ...                                  ...
# 5956            IBU RUMAH TANGGA    Rp. 900.001,- s/d Rp. 1.250.000,-
# 6330             Wiraswasta-Jasa  Rp. 1.250.001,- s/d Rp. 1.750.000,-
# 6351         Pegawai Swasta-Jasa  Rp. 1.750.001,- s/d Rp. 2.500.000,-
# 6501         Pegawai Swasta-Jasa  Rp. 1.250.001,- s/d Rp. 1.750.000,-
# 6674         Pegawai Swasta-Jasa  Rp. 1.250.001,- s/d Rp. 1.750.000,-
#
#            Pendidikan Varian Plus initial Varian Plus
# 12           SLTA/SMU         HZ3                   H
# 13            SARJANA         HWC                   H
# 24           SLTA/SMU         HDN                   H
# 31    AKADEMI/DIPLOMA         HZ3                   H
# 37           SLTA/SMU         HS2                   H
# ...               ...         ...                 ...
# 5956         SLTA/SMU         HDP                   H
# 6330         SLTA/SMU         HD7                   H
# 6351         SLTA/SMU         HJ9                   H
# 6501         SLTA/SMU         HDN                   H
# 6674         SLTA/SMU         HJ9                   H
#
# [447 rows x 12 columns]

# %%
df_H_count = df_H[["Tgl. Mohon"]].copy()
df_H_count["count"] = 1.
df_H_count = df_H_count.groupby("Tgl. Mohon").agg("count").reset_index()
df_H_count["cumulative_sum"] = df_H_count["count"].cumsum()
df_H_count
# Out:
#     Tgl. Mohon  count  cumulative_sum
# 0   2021-01-05      1               1
# 1   2021-01-06      1               2
# 2   2021-01-07      2               4
# 3   2021-01-09      1               5
# 4   2021-01-11      1               6
# ..         ...    ...             ...
# 295 2024-04-06      1             443
# 296 2024-06-06      1             444
# 297 2024-06-10      1             445
# 298 2024-07-08      1             446
# 299 2024-08-05      1             447
#
# [300 rows x 3 columns]

# %%
fig, ax = plt.subplots(figsize=(8, 3))

ax.plot(df_H_count["Tgl. Mohon"], df_H_count["cumulative_sum"], 
        linestyle="-", marker=".")

formatter = mdates.DateFormatter("%d/%m/%Y")
# locator = mdates.YearLocator(base=2)
locator = mdates.MonthLocator(bymonthday=1, bymonth=range(1, 13, 2))
ax.xaxis.set_major_formatter(formatter)
ax.xaxis.set_major_locator(locator)

ax.grid("on")
ax.set_xlabel("Tgl. Mohon")
ax.set_ylabel("Jumlah permohonan")

ax.set_title("df_H_count")

for j, label in enumerate(ax.get_xticklabels()):
  label.set_rotation(40)
  label.set_fontsize(8)
  label.set_horizontalalignment('right')

plt.show(fig)

# %% [markdown]
# Take initial varian plus "J"

# %%
df_J = df_cdb_with_initial[df_cdb_with_initial["initial Varian Plus"] == "J"].copy()
df_J
# Out:
#      Tgl. Mohon                 Nama                                 Alamat  \
# 150  2021-02-15             INDO ISA                        JL SEPAKU LAUT
# 414  2021-04-26  SENSILIA NONA ANITA                 JL SOEKARNO HATTA KM 9
# 449  2021-05-05           ZULKHAIDIR                  JL.WOLTER MONGINSIDI
# 576  2021-06-11        ABDUL RACHMAN                    VILLA DAMAI PERMAI
# 623  2021-06-25           PRESTIYONO           JL MULAWARMAN MANGGAR INDAH
# ...         ...                  ...                                    ...
# 6073 2024-04-30          AHMAD EKSAN                    BALIKPAPAN REGENCY
# 6176 2024-05-15      MOHAMMAD RISWAN             JL MAYOR POL ZAINAL ARIFIN
# 6374 2024-06-12         WATI KASWATI                      JL. GIRI REJO II
# 6534 2024-07-16       SUGENG PRIYONO  JL PRONA III PERUM BUKIT PRONA INDAH
# 6815 2024-08-27        DOFIANUS REGO                JL SOEKARNO-HATTA KM 9
#
#            Kelurahan           Kecamatan     Gender  Tgl. Lahir  \
# 150       MARGA SARI    BALIKPAPAN BARAT  PEREMPUAN  10/06/1989
# 414      GRAHA INDAH    BALIKPAPAN UTARA  PEREMPUAN  10/02/1983
# 449         BARU ULU    BALIKPAPAN BARAT  LAKI-LAKI  03/08/1975
# 576    GUNUNGBAHAGIA  BALIKPAPAN SELATAN  LAKI-LAKI  13/05/1967
# 623          MANGGAR    BALIKPAPAN TIMUR  LAKI-LAKI  15/08/1999
# ...              ...                 ...        ...         ...
# 6073  SEPINGGAN BARU  BALIKPAPAN SELATAN  LAKI-LAKI  31/08/1989
# 6176     SUMBER REJO   BALIKPAPAN TENGAH  LAKI-LAKI  13/08/1995
# 6374    KARANG JOANG    BALIKPAPAN UTARA  PEREMPUAN  21/12/1985
# 6534       SEPINGGAN  BALIKPAPAN SELATAN  LAKI-LAKI  02/09/1980
# 6815     GRAHA INDAH    BALIKPAPAN UTARA  LAKI-LAKI  23/05/1993
#
#                         Pekerjaan                          Pengeluaran  \
# 150        Wiraswasta-Perdagangan                      < Rp. 900.000,-
# 414              IBU RUMAH TANGGA    Rp. 900.001,- s/d Rp. 1.250.000,-
# 449                     LAIN-LAIN    Rp. 900.001,- s/d Rp. 1.250.000,-
# 576    Pegawai Swasta-Perdagangan    Rp. 900.001,- s/d Rp. 1.250.000,-
# 623             MAHASISWA/PELAJAR    Rp. 900.001,- s/d Rp. 1.250.000,-
# ...                           ...                                  ...
# 6073          Pegawai Swasta-Jasa    Rp. 900.001,- s/d Rp. 1.250.000,-
# 6176  Pegawai Swasta-Pertambangan  Rp. 2.500.001,- s/d Rp. 4.000.000,-
# 6374             IBU RUMAH TANGGA  Rp. 1.750.001,- s/d Rp. 2.500.000,-
# 6534          Pegawai Swasta-Jasa  Rp. 1.250.001,- s/d Rp. 1.750.000,-
# 6815          Pegawai Swasta-Jasa  Rp. 1.250.001,- s/d Rp. 1.750.000,-
#
#      Pendidikan Varian Plus initial Varian Plus
# 150    SLTA/SMU         JM0                   J
# 414    SLTA/SMU         JMB                   J
# 449    SLTA/SMU         JMB                   J
# 576    SLTA/SMU         JM0                   J
# 623    SLTA/SMU         JN0                   J
# ...         ...         ...                 ...
# 6073   SLTA/SMU         JMG                   J
# 6176   SLTA/SMU         JM1                   J
# 6374   SLTA/SMU         JMH                   J
# 6534   SLTA/SMU         JS0                   J
# 6815   SLTA/SMU         JS0                   J
#
# [84 rows x 12 columns]

# %%
df_J_count = df_J[["Tgl. Mohon"]].copy()
df_J_count["count"] = 1.
df_J_count = df_J_count.groupby("Tgl. Mohon").agg("count").reset_index()
df_J_count["cumulative_sum"] = df_J_count["count"].cumsum()
df_J_count
# Out:
#    Tgl. Mohon  count  cumulative_sum
# 0  2021-02-15      1               1
# 1  2021-04-26      1               2
# 2  2021-05-05      1               3
# 3  2021-06-11      1               4
# 4  2021-06-25      1               5
# ..        ...    ...             ...
# 75 2024-04-30      1              80
# 76 2024-05-15      1              81
# 77 2024-06-12      1              82
# 78 2024-07-16      1              83
# 79 2024-08-27      1              84
#
# [80 rows x 3 columns]

# %%
fig, ax = plt.subplots(figsize=(8, 3))

ax.plot(df_J_count["Tgl. Mohon"], df_J_count["cumulative_sum"], 
        linestyle="-", marker=".")

formatter = mdates.DateFormatter("%d/%m/%Y")
# locator = mdates.YearLocator(base=2)
locator = mdates.MonthLocator(bymonthday=1, bymonth=range(1, 13, 2))
ax.xaxis.set_major_formatter(formatter)
ax.xaxis.set_major_locator(locator)

ax.grid("on")
ax.set_xlabel("Tgl. Mohon")
ax.set_ylabel("Jumlah permohonan")

ax.set_title("df_J_count")

for j, label in enumerate(ax.get_xticklabels()):
  label.set_rotation(40)
  label.set_fontsize(8)
  label.set_horizontalalignment('right')

plt.show(fig)

# %% [markdown]
# Take initial varian plus "L"

# %%
df_L = df_cdb_with_initial[df_cdb_with_initial["initial Varian Plus"] == "L"].copy()
df_L
# Out:
#      Tgl. Mohon                         Nama                           Alamat  \
# 0    2021-01-02                       MULKAN                  JL AL MAKMUR I
# 1    2021-01-02          HANIE ZULFA NABIELA  JL MT HARYONO PERUM GRAND CITY
# 2    2021-01-02                 HASANA PUTRI              JL LETJEND S PARMAN
# 3    2021-01-02                  SUSARI HATI           JL MARSMA R ISWAHYUDI
# 4    2021-01-02                 ROY KILAPONG                    JL MT HARYONO
# ...         ...                          ...                              ...
# 6847 2024-08-31                       IMELDA               SUMBER JAYA TIMUR
# 6849 2024-08-31     HANIF IHABULLAH IFTIKHAR                      JL PENEGAK
# 6850 2024-08-31  FAHREL SAJDAH RIFQIYA LEMAN           JL. MARSMA R ISWAHYUDI
# 6854 2024-08-31             JAMES HAROL SELA          JL. LETJEND. S. PARMAN
# 6856 2024-08-31            NURIANI PATANDEAN                JL BONTO BULAENG
#
#            Kelurahan           Kecamatan     Gender  Tgl. Lahir  \
# 0              DAMAI     BALIKPAPAN KOTA  LAKI-LAKI  18/08/1996
# 1        GRAHA INDAH    BALIKPAPAN UTARA  PEREMPUAN  14/04/2003
# 2        SUMBER REJO   BALIKPAPAN TENGAH  PEREMPUAN  13/02/1997
# 3       SUNGAINANGKA  BALIKPAPAN SELATAN  PEREMPUAN  16/11/1982
# 4      DAMAI BAHAGIA  BALIKPAPAN SELATAN  LAKI-LAKI  17/01/1976
# ...              ...                 ...        ...         ...
# 6847    SEPASO BARAT            BENGALON  PEREMPUAN  20/07/2004
# 6849   DAMAI BAHAGIA  BALIKPAPAN SELATAN  LAKI-LAKI  01/04/2005
# 6850  SEPINGGAN RAYA  BALIKPAPAN SELATAN  LAKI-LAKI  21/03/1973
# 6854  GUNUNGSARI ULU   BALIKPAPAN TENGAH  LAKI-LAKI  19/01/1961
# 6856     SUMBER REJO   BALIKPAPAN TENGAH  PEREMPUAN  08/04/1993
#
#                      Pekerjaan                          Pengeluaran  \
# 0              Wiraswasta-Jasa  Rp. 1.750.001,- s/d Rp. 2.500.000,-
# 1          Pegawai Swasta-Jasa                      < Rp. 900.000,-
# 2     Pegawai Swasta-Pertanian    Rp. 900.001,- s/d Rp. 1.250.000,-
# 3      Pegawai Swasta-Industri  Rp. 4.000.001,- s/d Rp. 6.000.000,-
# 4          Pegawai Swasta-Jasa  Rp. 2.500.001,- s/d Rp. 4.000.000,-
# ...                        ...                                  ...
# 6847         MAHASISWA/PELAJAR  Rp. 1.250.001,- s/d Rp. 1.750.000,-
# 6849         MAHASISWA/PELAJAR                      < Rp. 900.000,-
# 6850       Pegawai Swasta-Jasa  Rp. 1.250.001,- s/d Rp. 1.750.000,-
# 6854       Pegawai Swasta-Jasa  Rp. 1.750.001,- s/d Rp. 2.500.000,-
# 6856          IBU RUMAH TANGGA    Rp. 900.001,- s/d Rp. 1.250.000,-
#
#            Pendidikan Varian Plus initial Varian Plus
# 0            SLTP/SMP         LD0                   L
# 1     AKADEMI/DIPLOMA         LP0                   L
# 2             SARJANA         LPA                   L
# 3            SLTA/SMU         LP0                   L
# 4            SLTA/SMU         LPA                   L
# ...               ...         ...                 ...
# 6847         SLTA/SMU         LP3                   L
# 6849         SLTA/SMU         LVE                   L
# 6850         SLTA/SMU         LV1                   L
# 6854          SARJANA         LP3                   L
# 6856         SLTA/SMU         LW1                   L
#
# [5130 rows x 12 columns]

# %%
df_L_count = df_L[["Tgl. Mohon"]].copy()
df_L_count["count"] = 1.
df_L_count = df_L_count.groupby("Tgl. Mohon").agg("count").reset_index()
df_L_count["cumulative_sum"] = df_L_count["count"].cumsum()
df_L_count
# Out:
#      Tgl. Mohon  count  cumulative_sum
# 0    2021-01-02      5               5
# 1    2021-01-04      2               7
# 2    2021-01-05      3              10
# 3    2021-01-06      4              14
# 4    2021-01-07      7              21
# ...         ...    ...             ...
# 1064 2024-08-27      2            5118
# 1065 2024-08-28      1            5119
# 1066 2024-08-29      3            5122
# 1067 2024-08-30      2            5124
# 1068 2024-08-31      6            5130
#
# [1069 rows x 3 columns]

# %%
fig, ax = plt.subplots(figsize=(8, 3))

ax.plot(df_L_count["Tgl. Mohon"], df_L_count["cumulative_sum"], 
        linestyle="-", marker=".")

formatter = mdates.DateFormatter("%d/%m/%Y")
# locator = mdates.YearLocator(base=2)
locator = mdates.MonthLocator(bymonthday=1, bymonth=range(1, 13, 2))
ax.xaxis.set_major_formatter(formatter)
ax.xaxis.set_major_locator(locator)

ax.grid("on")
ax.set_xlabel("Tgl. Mohon")
ax.set_ylabel("Jumlah permohonan")

ax.set_title("df_L_count")

for j, label in enumerate(ax.get_xticklabels()):
  label.set_rotation(40)
  label.set_fontsize(8)
  label.set_horizontalalignment('right')

plt.show(fig)

# %% [markdown]
# Take initial varian plus "M"

# %%
df_M = df_cdb_with_initial[df_cdb_with_initial["initial Varian Plus"] == "M"].copy()
df_M
# Out:
#      Tgl. Mohon                      Nama  \
# 2216 2022-07-26               ACHMAD YANI
# 2262 2022-08-08             NURUL HASANAH
# 2267 2022-08-10             HERU BADRUDIN
# 2472 2022-09-19  RISWAN FEBRIYANTO BATARA
# 2513 2022-09-23   PT HARAPAN UTAMA MAKMUR
# ...         ...                       ...
# 6848 2024-08-31      DODI PRATAMA SUHARSO
# 6851 2024-08-31            SUSAN HADINATA
# 6852 2024-08-31                 RUDI AMSA
# 6853 2024-08-31                   MARIATI
# 6855 2024-08-31    GOMGOM RAULI SIHOMBING
#
#                                       Alamat      Kelurahan  \
# 2216                       JL JEND SUDIRMAN           DAMAI
# 2262             JL. SEPAKU LAUT GANG RUKUN      MARGA SARI
# 2267  PERUM GRIYA PERMATA ASRI JL.MC KENZIE   GUNUNGBAHAGIA
# 2472                    JL. DAKSA TIMUR XIII      SEPINGGAN
# 2513                           JL MT HARYONO          DAMAI
# ...                                      ...            ...
# 6848                      BATU AMPAR PERMAL     GRAHA INDAH
# 6851                          JL. S. PARMAN     SUMBER REJO
# 6852                         JL PADAT KARYA         MANGGAR
# 6853                   JL. TAMAN BUKIT SARI     GRAHA INDAH
# 6855                           PERUM BDS II    SUNGAINANGKA
#
#                Kecamatan     Gender  Tgl. Lahir                   Pekerjaan  \
# 2216  BALIKPAPAN SELATAN  LAKI-LAKI  22/06/1980      Wiraswasta-Perdagangan
# 2262    BALIKPAPAN BARAT  PEREMPUAN  02/02/1989            IBU RUMAH TANGGA
# 2267  BALIKPAPAN SELATAN  LAKI-LAKI  05/03/1988  Pegawai Swasta-Perdagangan
# 2472  BALIKPAPAN SELATAN  LAKI-LAKI  25/02/1994    Pegawai Swasta-Pertanian
# 2513     BALIKPAPAN KOTA        NaN  18/07/1979                         NaN
# ...                  ...        ...         ...                         ...
# 6848    BALIKPAPAN UTARA  LAKI-LAKI  03/11/1989         Pegawai Swasta-Jasa
# 6851   BALIKPAPAN TENGAH  PEREMPUAN  20/09/1983            IBU RUMAH TANGGA
# 6852    BALIKPAPAN TIMUR  LAKI-LAKI  06/11/2004         Pegawai Swasta-Jasa
# 6853    BALIKPAPAN UTARA  PEREMPUAN  21/03/1978         Pegawai Swasta-Jasa
# 6855  BALIKPAPAN SELATAN  PEREMPUAN  30/04/1980            IBU RUMAH TANGGA
#
#                               Pengeluaran Pendidikan Varian Plus  \
# 2216  Rp. 2.500.001,- s/d Rp. 4.000.000,-   SLTA/SMU         MA0
# 2262  Rp. 2.500.001,- s/d Rp. 4.000.000,-   SLTA/SMU         MB0
# 2267  Rp. 2.500.001,- s/d Rp. 4.000.000,-   SLTA/SMU         MB0
# 2472  Rp. 2.500.001,- s/d Rp. 4.000.000,-   SLTA/SMU         MB0
# 2513                                  NaN        NaN         MB0
# ...                                   ...        ...         ...
# 6848  Rp. 2.500.001,- s/d Rp. 4.000.000,-    SARJANA         ML0
# 6851  Rp. 1.750.001,- s/d Rp. 2.500.000,-   SLTA/SMU         MD1
# 6852    Rp. 900.001,- s/d Rp. 1.250.000,-   SLTA/SMU         MM0
# 6853  Rp. 1.750.001,- s/d Rp. 2.500.000,-   SLTA/SMU         MM0
# 6855  Rp. 1.250.001,- s/d Rp. 1.750.000,-   SLTA/SMU         ML0
#
#      initial Varian Plus
# 2216                   M
# 2262                   M
# 2267                   M
# 2472                   M
# 2513                   M
# ...                  ...
# 6848                   M
# 6851                   M
# 6852                   M
# 6853                   M
# 6855                   M
#
# [533 rows x 12 columns]

# %%
df_M_count = df_M[["Tgl. Mohon"]].copy()
df_M_count["count"] = 1.
df_M_count = df_M_count.groupby("Tgl. Mohon").agg("count").reset_index()
df_M_count["cumulative_sum"] = df_M_count["count"].cumsum()
df_M_count
# Out:
#     Tgl. Mohon  count  cumulative_sum
# 0   2022-07-26      1               1
# 1   2022-08-08      1               2
# 2   2022-08-10      1               3
# 3   2022-09-19      1               4
# 4   2022-09-23      2               6
# ..         ...    ...             ...
# 283 2024-08-27      2             510
# 284 2024-08-28      5             515
# 285 2024-08-29      6             521
# 286 2024-08-30      3             524
# 287 2024-08-31      9             533
#
# [288 rows x 3 columns]

# %%
fig, ax = plt.subplots(figsize=(8, 3))

ax.plot(df_M_count["Tgl. Mohon"], df_M_count["cumulative_sum"], 
        linestyle="-", marker=".")

formatter = mdates.DateFormatter("%d/%m/%Y")
# locator = mdates.YearLocator(base=2)
locator = mdates.MonthLocator(bymonthday=1, bymonth=range(1, 13, 2))
ax.xaxis.set_major_formatter(formatter)
ax.xaxis.set_major_locator(locator)

ax.grid("on")
ax.set_xlabel("Tgl. Mohon")
ax.set_ylabel("Jumlah permohonan")

ax.set_title("df_M_count")

for j, label in enumerate(ax.get_xticklabels()):
  label.set_rotation(40)
  label.set_fontsize(8)
  label.set_horizontalalignment('right')

plt.show(fig)
