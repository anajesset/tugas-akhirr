# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib as mpl
import pandas as pd
import seaborn as sns
import scipy.stats as stats

# %%
plt.rcParams.update(plt.rcParamsDefault)
plt.rcParams.update({
  "font.size": 16,
  "grid.alpha": 0.25})

# %% [markdown]
# ### Pre-processing

# %%
file_path = "./data/stock_barang.csv"
df_stock = pd.read_csv(file_path)
df_stock["Bulan"] = pd.to_datetime(df_stock["Bulan"], format="%b-%y")
df_stock
# Out:
#           Bulan Kode MD  Kode Dealer AHM  Kode Dealer SAP     No. Mesin  \
# 0    2021-01-01     R4Z             1858       5200022541  JM61E1126463
# 1    2021-01-01     R4Z             1858       5200022541  JM61E1128750
# 2    2021-01-01     R4Z             1858       5200022541  JM61E1129395
# 3    2021-01-01     R4Z             1858       5200022541  JM91E1288702
# 4    2021-01-01     R4Z             1858       5200022541  JM91E1295308
# ...         ...     ...              ...              ...           ...
# 2632 2024-08-01     R4Z             1858       5200022541  KFB1E1087704
# 2633 2024-08-01     R4Z             1858       5200022541  KFB1E1089792
# 2634 2024-08-01     R4Z             1858       5200022541  KFB1E1090542
# 2635 2024-08-01     R4Z             1858       5200022541  KFB2E1052137
# 2636 2024-08-01     R4Z             1858       5200022541  KFC1E1046262
#
#           No. Rangka Kode Tipe AHM Kode Tipe
# 0     JM6112LK138354           LD0       LD0
# 1     JM6110LK129071           LD0       LD0
# 2     JM6112LK129394           LD0       LD0
# 3     JM9114LK290539           LK0      LK0A
# 4     JM9110LK294474           LK0      LK0A
# ...              ...           ...       ...
# 2632  KFB119RK087757           MA0       MA0
# 2633  KFB116RK089966           MA0       MA0
# 2634  KFB118RK090522           MA0       MA0
# 2635  KFB219RK052098           MB0       MB0
# 2636  KFC116RK046038           MF0       MF0
#
# [2637 rows x 8 columns]

# %%
df_stock_initial = df_stock.copy()
df_stock_initial["initial Varian Plus"] = df_stock_initial["Kode Tipe AHM"].apply(lambda x: x[0])
df_stock_initial
# Out:
#           Bulan Kode MD  Kode Dealer AHM  Kode Dealer SAP     No. Mesin  \
# 0    2021-01-01     R4Z             1858       5200022541  JM61E1126463
# 1    2021-01-01     R4Z             1858       5200022541  JM61E1128750
# 2    2021-01-01     R4Z             1858       5200022541  JM61E1129395
# 3    2021-01-01     R4Z             1858       5200022541  JM91E1288702
# 4    2021-01-01     R4Z             1858       5200022541  JM91E1295308
# ...         ...     ...              ...              ...           ...
# 2632 2024-08-01     R4Z             1858       5200022541  KFB1E1087704
# 2633 2024-08-01     R4Z             1858       5200022541  KFB1E1089792
# 2634 2024-08-01     R4Z             1858       5200022541  KFB1E1090542
# 2635 2024-08-01     R4Z             1858       5200022541  KFB2E1052137
# 2636 2024-08-01     R4Z             1858       5200022541  KFC1E1046262
#
#           No. Rangka Kode Tipe AHM Kode Tipe initial Varian Plus
# 0     JM6112LK138354           LD0       LD0                   L
# 1     JM6110LK129071           LD0       LD0                   L
# 2     JM6112LK129394           LD0       LD0                   L
# 3     JM9114LK290539           LK0      LK0A                   L
# 4     JM9110LK294474           LK0      LK0A                   L
# ...              ...           ...       ...                 ...
# 2632  KFB119RK087757           MA0       MA0                   M
# 2633  KFB116RK089966           MA0       MA0                   M
# 2634  KFB118RK090522           MA0       MA0                   M
# 2635  KFB219RK052098           MB0       MB0                   M
# 2636  KFC116RK046038           MF0       MF0                   M
#
# [2637 rows x 9 columns]

# %%
df_stock_count = df_stock_initial[["initial Varian Plus"]].copy()
df_stock_count["count"] = 1.
df_stock_count = df_stock_count.groupby("initial Varian Plus").agg("count").reset_index()
df_stock_count
# Out:
#   initial Varian Plus  count
# 0                   E    310
# 1                   G    105
# 2                   H    316
# 3                   J    279
# 4                   L   1478
# 5                   M    149

# %%
fig, ax = plt.subplots(figsize=(10, 6))

# because pandas includes right endpoint, we must subtract by one
x_data = df_stock_count["initial Varian Plus"]
y_data = df_stock_count["count"]
ax.bar(x_data, y_data)

ax.set_xticks(np.arange(len(x_data)))
ax.set_xticklabels(x_data, rotation=45, fontsize=8)

ax.set_ylim([0, 1500])

plt.subplots_adjust(hspace=0.3)
plt.show()

# %% [markdown]
# ### Varian E

# %%
df_stock_E = df_stock_initial[df_stock_initial["initial Varian Plus"] == "E"].copy()
df_stock_E
# Out:
#           Bulan Kode MD  Kode Dealer AHM  Kode Dealer SAP     No. Mesin  \
# 15   2021-01-01     R4Z             1858       5200022541  KC92E1049384
# 16   2021-01-01     R4Z             1858       5200022541  KC93E1013569
# 17   2021-01-01     R4Z             1858       5200022541  KCA2E1084088
# 89   2021-02-01     R4Z              576       5200022542  KC01E1067808
# 90   2021-02-01     R4Z              576       5200022542  KC01E1067839
# ...         ...     ...              ...              ...           ...
# 2607 2024-08-01     R4Z             1858       5200022541  KD11E1517658
# 2608 2024-08-01     R4Z             1858       5200022541  KD11E1517700
# 2609 2024-08-01     R4Z             1858       5200022541  KD11E1519227
# 2610 2024-08-01     R4Z             1858       5200022541  KD11E1519229
# 2611 2024-08-01     R4Z             1858       5200022541  KD11E1535042
#
#           No. Rangka Kode Tipe AHM Kode Tipe initial Varian Plus
# 15    KC9217LK051850           EXF       EXF                   E
# 16    KC9315LK012477           EYE       EYE                   E
# 17    KCA210LK088546           EW2       EW2                   E
# 89    KC0118RK067819           EH2       EH2                   E
# 90    KC0110RK067829           EH2       EH2                   E
# ...              ...           ...       ...                 ...
# 2607  KD1115RK518417           ESE       ESE                   E
# 2608  KD1111RK518463           ESE       ESE                   E
# 2609  KD1113RK519937           ESE       ESE                   E
# 2610  KD1113RK519940           ESE       ESE                   E
# 2611  KD1119RK535883           ESF       ESF                   E
#
# [310 rows x 9 columns]

# %%
df_E_count = df_stock_E[["Bulan"]].copy()
df_E_count["count"] = 1.
df_E_count = df_E_count.groupby("Bulan").agg("count").reset_index()
df_E_count
# Out:
#         Bulan  count
# 0  2021-01-01      3
# 1  2021-02-01     27
# 2  2021-03-01      2
# 3  2021-04-01      2
# 4  2021-05-01      1
# 5  2021-10-01      2
# 6  2022-03-01      3
# 7  2022-10-01      1
# 8  2022-11-01      1
# 9  2022-12-01      2
# 10 2023-02-01      2
# 11 2023-03-01      6
# 12 2023-04-01      3
# 13 2023-05-01      2
# 14 2023-06-01     55
# 15 2023-07-01     55
# 16 2023-08-01     45
# 17 2023-09-01      1
# 18 2023-10-01      4
# 19 2023-11-01      2
# 20 2023-12-01      3
# 21 2024-01-01      1
# 22 2024-02-01      7
# 23 2024-03-01      5
# 24 2024-04-01      9
# 25 2024-05-01      9
# 26 2024-06-01      6
# 27 2024-07-01      9
# 28 2024-08-01     42

# %%
df_E_count["Bulan"] = pd.to_datetime(df_E_count["Bulan"])

# %%
fig, ax = plt.subplots(figsize=(8, 3))

ax.plot(df_E_count["Bulan"], df_E_count["count"], linestyle="-",
        marker=".")

formatter = mdates.DateFormatter("%b-%y")
# locator = mdates.YearLocator(base=2)
# locator = mdates.MonthLocator(bymonthday=1, bymonth=range(1, 13, 1))
locator = mdates.MonthLocator()
ax.xaxis.set_major_formatter(formatter)
ax.xaxis.set_major_locator(locator)

ax.grid("on")
ax.set_xlabel("Bulan")
ax.set_ylabel("Jumlah Stok")

ax.set_title("Varian E")

for j, label in enumerate(ax.get_xticklabels()):
  label.set_rotation(40)
  label.set_size(8)
  label.set_horizontalalignment('right')

plt.show(fig)

# %% [markdown]
# ### Varian G

# %%
df_stock_G = df_stock_initial[df_stock_initial["initial Varian Plus"] == "G"].copy()
df_stock_G
# Out:
#           Bulan Kode MD  Kode Dealer AHM  Kode Dealer SAP     No. Mesin  \
# 25   2021-02-01     R4Z              576       5200022542  JBK1E2006377
# 26   2021-02-01     R4Z              576       5200022542  JBK1E2045918
# 27   2021-02-01     R4Z              576       5200022542  JBN1E1241723
# 28   2021-02-01     R4Z              576       5200022542  JBP1E2067533
# 29   2021-02-01     R4Z              576       5200022542  JBP1E2068620
# ...         ...     ...              ...              ...           ...
# 2433 2024-08-01     R4Z             1858       5200022541  JBK3E1533475
# 2434 2024-08-01     R4Z             1858       5200022541  JBN1E1237935
# 2435 2024-08-01     R4Z             1858       5200022541  JBP1E2050174
# 2436 2024-08-01     R4Z             1858       5200022541  JBP1E2058759
# 2437 2024-08-01     R4Z             1858       5200022541  JBP1E2059570
#
#           No. Rangka Kode Tipe AHM Kode Tipe initial Varian Plus
# 25    JBK129RK008796           GB4       GB4                   G
# 26    JBK125RK048292           GB4       GB4                   G
# 27    JBN112RK241671           GE5       GE5                   G
# 28    JBP122RK067301           GF5       GF5                   G
# 29    JBP122RK068528           GF5       GF5                   G
# ...              ...           ...       ...                 ...
# 2433  JBK316RK535179           GD4       GD4                   G
# 2434  JBN11XRK237903           GE5       GE5                   G
# 2435  JBP124RK049933           GF5       GF5                   G
# 2436  JBP122RK058629           GF5       GF5                   G
# 2437  JBP124RK059510           GF5       GF5                   G
#
# [105 rows x 9 columns]

# %%
df_G_count = df_stock_G[["Bulan"]].copy()
df_G_count["count"] = 1.
df_G_count = df_G_count.groupby("Bulan").agg("count").reset_index()
df_G_count
# Out:
#         Bulan  count
# 0  2021-02-01      5
# 1  2021-03-01      2
# 2  2021-04-01      2
# 3  2021-05-01      2
# 4  2021-06-01      2
# 5  2021-07-01      3
# 6  2021-09-01      1
# 7  2022-03-01      2
# 8  2022-04-01     12
# 9  2022-05-01      4
# 10 2022-06-01      6
# 11 2022-08-01      1
# 12 2022-10-01      1
# 13 2022-11-01      1
# 14 2022-12-01      1
# 15 2023-02-01      3
# 16 2023-04-01      1
# 17 2023-05-01      3
# 18 2023-06-01      3
# 19 2023-07-01      3
# 20 2023-08-01      1
# 21 2023-09-01      2
# 22 2023-10-01      1
# 23 2023-12-01      1
# 24 2024-02-01     11
# 25 2024-03-01      6
# 26 2024-04-01      6
# 27 2024-05-01      6
# 28 2024-06-01      4
# 29 2024-07-01      2
# 30 2024-08-01      7

# %%
df_G_count["Bulan"] = pd.to_datetime(df_G_count["Bulan"])

# %%
fig, ax = plt.subplots(figsize=(8, 3))

ax.plot(df_G_count["Bulan"], df_G_count["count"], linestyle="-",
        marker=".")

formatter = mdates.DateFormatter("%b-%y")
# locator = mdates.YearLocator(base=2)
# locator = mdates.MonthLocator(bymonthday=1, bymonth=range(1, 13, 1))
locator = mdates.MonthLocator()
ax.xaxis.set_major_formatter(formatter)
ax.xaxis.set_major_locator(locator)

ax.grid("on")
ax.set_xlabel("Bulan")
ax.set_ylabel("Jumlah Stok")

ax.set_title("Varian G")

for j, label in enumerate(ax.get_xticklabels()):
  label.set_rotation(40)
  label.set_size(8)
  label.set_horizontalalignment('right')

plt.show(fig)

# %% [markdown]
# ### Varian H

# %%
df_stock_H = df_stock_initial[df_stock_initial["initial Varian Plus"] == "H"].copy()
df_stock_H
# Out:
#           Bulan Kode MD  Kode Dealer AHM  Kode Dealer SAP     No. Mesin  \
# 6    2021-01-01     R4Z             1858       5200022541  KB11E1244261
# 7    2021-01-01     R4Z             1858       5200022541  KB22E1007332
# 8    2021-01-01     R4Z             1858       5200022541  KB22E1008213
# 9    2021-01-01     R4Z             1858       5200022541  KB22E1008751
# 10   2021-01-01     R4Z             1858       5200022541  KB22E1008800
# ...         ...     ...              ...              ...           ...
# 2382 2024-07-01     R4Z             1858       5200022541  KB22E1046282
# 2552 2024-08-01     R4Z             1858       5200022541  KB11E1351610
# 2553 2024-08-01     R4Z             1858       5200022541  KB22E1044483
# 2554 2024-08-01     R4Z             1858       5200022541  KB22E1046282
# 2555 2024-08-01     R4Z             1858       5200022541  KB22E1051670
#
#           No. Rangka Kode Tipe AHM Kode Tipe initial Varian Plus
# 6     KB1116LK244786           HDN       HDN                   H
# 7     KB2219LK007374           HJK       HJK                   H
# 8     KB2214LK008237           HJK       HJK                   H
# 9     KB2213LK008892           HJ9       HJ9                   H
# 10    KB2214LK008948           HJ9       HJ9                   H
# ...              ...           ...       ...                 ...
# 2382  KB221XRK046371           HJ9       HJ9                   H
# 2552  KB1117RK352083           HDP       HDP                   H
# 2553  KB2215RK044639           HJ9       HJ9                   H
# 2554  KB221XRK046371           HJ9       HJ9                   H
# 2555  KB2213RK051850           HJ9       HJ9                   H
#
# [316 rows x 9 columns]

# %%
df_H_count = df_stock_H[["Bulan"]].copy()
df_H_count["count"] = 1.
df_H_count = df_H_count.groupby("Bulan").agg("count").reset_index()
df_H_count
# Out:
#         Bulan  count
# 0  2021-01-01     16
# 1  2021-02-01      4
# 2  2021-03-01     17
# 3  2021-04-01     32
# 4  2021-05-01     20
# 5  2021-06-01     18
# 6  2021-07-01     10
# 7  2021-08-01     14
# 8  2021-09-01     17
# 9  2021-10-01     26
# 10 2021-11-01     13
# 11 2021-12-01      9
# 12 2022-01-01      7
# 13 2022-02-01      7
# 14 2022-03-01      3
# 15 2022-04-01      3
# 16 2022-06-01      1
# 17 2022-10-01      1
# 18 2023-02-01      4
# 19 2023-03-01      6
# 20 2023-04-01      5
# 21 2023-05-01      4
# 22 2023-06-01      4
# 23 2023-07-01      4
# 24 2023-08-01      5
# 25 2023-09-01      5
# 26 2023-10-01      6
# 27 2023-11-01      5
# 28 2023-12-01      5
# 29 2024-01-01      5
# 30 2024-02-01      7
# 31 2024-03-01      7
# 32 2024-04-01      6
# 33 2024-05-01      6
# 34 2024-06-01      6
# 35 2024-07-01      4
# 36 2024-08-01      4

# %%
df_H_count["Bulan"] = pd.to_datetime(df_H_count["Bulan"])

# %%
fig, ax = plt.subplots(figsize=(8, 3))

ax.plot(df_H_count["Bulan"], df_H_count["count"], linestyle="-",
        marker=".")

formatter = mdates.DateFormatter("%b-%y")
# locator = mdates.YearLocator(base=2)
# locator = mdates.MonthLocator(bymonthday=1, bymonth=range(1, 13, 1))
locator = mdates.MonthLocator()
ax.xaxis.set_major_formatter(formatter)
ax.xaxis.set_major_locator(locator)

ax.grid("on")
ax.set_xlabel("Bulan")
ax.set_ylabel("Jumlah Stok")

ax.set_title("Varian H")

for j, label in enumerate(ax.get_xticklabels()):
  label.set_rotation(40)
  label.set_size(8)
  label.set_horizontalalignment('right')

plt.show(fig)

# %% [markdown]
# ### Varian J

# %%
df_stock_J = df_stock_initial[df_stock_initial["initial Varian Plus"] == "J"].copy()
df_stock_J
# Out:
#           Bulan Kode MD  Kode Dealer AHM  Kode Dealer SAP     No. Mesin  \
# 107  2021-02-01     R4Z              576       5200022542  KCC1E1013645
# 108  2021-02-01     R4Z              576       5200022542  KCD1E1020221
# 109  2021-02-01     R4Z              576       5200022542  KCD2E1046363
# 110  2021-02-01     R4Z              576       5200022542  KCD2E1046663
# 111  2021-02-01     R4Z              576       5200022542  KCE1E1018566
# ...         ...     ...              ...              ...           ...
# 2599 2024-08-01     R4Z             1858       5200022541  KCE1E1019133
# 2600 2024-08-01     R4Z             1858       5200022541  KCE1E1023003
# 2601 2024-08-01     R4Z             1858       5200022541  KCE1E1025413
# 2602 2024-08-01     R4Z             1858       5200022541  KCE1E1025555
# 2603 2024-08-01     R4Z             1858       5200022541  KCE1E1025646
#
#           No. Rangka Kode Tipe AHM Kode Tipe initial Varian Plus
# 107   KCC119PK013704           JNT       JNT                   J
# 108   KCD110RK020288           JR0       JR0                   J
# 109   KCD213RK046494           JS0       JS0                   J
# 110   KCD219RK046712           JS0       JS0                   J
# 111   KCE112PK018495           JXA       JXA                   J
# ...              ...           ...       ...                 ...
# 2599  KCE116PK019309           JX0       JX0                   J
# 2600  KCE114PK023102           JXA       JXA                   J
# 2601  KCE112RK025594           JX0       JX0                   J
# 2602  KCE112RK025787           JX0       JX0                   J
# 2603  KCE111RK025845           JXA       JXA                   J
#
# [279 rows x 9 columns]

# %%
df_J_count = df_stock_J[["Bulan"]].copy()
df_J_count["count"] = 1.
df_J_count = df_J_count.groupby("Bulan").agg("count").reset_index()
df_J_count
# Out:
#         Bulan  count
# 0  2021-02-01     12
# 1  2021-03-01      1
# 2  2021-04-01      1
# 3  2021-05-01      1
# 4  2021-07-01      2
# 5  2021-08-01      2
# 6  2021-09-01      2
# 7  2021-10-01      3
# 8  2021-11-01      3
# 9  2021-12-01      3
# 10 2022-01-01      1
# 11 2022-02-01      1
# 12 2022-03-01      8
# 13 2022-04-01      6
# 14 2022-05-01     10
# 15 2022-06-01     10
# 16 2022-07-01      5
# 17 2022-08-01      4
# 18 2022-09-01      2
# 19 2022-10-01      2
# 20 2022-11-01      5
# 21 2022-12-01      5
# 22 2023-01-01      4
# 23 2023-02-01      8
# 24 2023-03-01      9
# 25 2023-04-01      4
# 26 2023-05-01      3
# 27 2023-06-01      5
# 28 2023-07-01      5
# 29 2023-08-01     12
# 30 2023-09-01      9
# 31 2023-10-01      9
# 32 2023-11-01      9
# 33 2023-12-01      9
# 34 2024-01-01      8
# 35 2024-02-01      9
# 36 2024-03-01     15
# 37 2024-04-01     13
# 38 2024-05-01     13
# 39 2024-06-01     16
# 40 2024-07-01     16
# 41 2024-08-01     14

# %%
df_J_count["Bulan"] = pd.to_datetime(df_J_count["Bulan"])

# %%
fig, ax = plt.subplots(figsize=(8, 3))

ax.plot(df_J_count["Bulan"], df_J_count["count"], linestyle="-",
        marker=".")

formatter = mdates.DateFormatter("%b-%y")
# locator = mdates.YearLocator(base=2)
# locator = mdates.MonthLocator(bymonthday=1, bymonth=range(1, 13, 1))
locator = mdates.MonthLocator()
ax.xaxis.set_major_formatter(formatter)
ax.xaxis.set_major_locator(locator)

ax.grid("on")
ax.set_xlabel("Bulan")
ax.set_ylabel("Jumlah Stok")

ax.set_title("Varian J")

for j, label in enumerate(ax.get_xticklabels()):
  label.set_rotation(40)
  label.set_size(8)
  label.set_horizontalalignment('right')

plt.show(fig)

# %% [markdown]
# ### Varian L

# %%
df_stock_L = df_stock_initial[df_stock_initial["initial Varian Plus"] == "L"].copy()
df_stock_L
# Out:
#           Bulan Kode MD  Kode Dealer AHM  Kode Dealer SAP     No. Mesin  \
# 0    2021-01-01     R4Z             1858       5200022541  JM61E1126463
# 1    2021-01-01     R4Z             1858       5200022541  JM61E1128750
# 2    2021-01-01     R4Z             1858       5200022541  JM61E1129395
# 3    2021-01-01     R4Z             1858       5200022541  JM91E1288702
# 4    2021-01-01     R4Z             1858       5200022541  JM91E1295308
# ...         ...     ...              ...              ...           ...
# 2625 2024-08-01     R4Z             1858       5200022541  KFA1E1203856
# 2626 2024-08-01     R4Z             1858       5200022541  KFA1E1247727
# 2627 2024-08-01     R4Z             1858       5200022541  KFA1E1249969
# 2628 2024-08-01     R4Z             1858       5200022541  KFA1E1253732
# 2629 2024-08-01     R4Z             1858       5200022541  KFA1E1253749
#
#           No. Rangka Kode Tipe AHM Kode Tipe initial Varian Plus
# 0     JM6112LK138354           LD0       LD0                   L
# 1     JM6110LK129071           LD0       LD0                   L
# 2     JM6112LK129394           LD0       LD0                   L
# 3     JM9114LK290539           LK0      LK0A                   L
# 4     JM9110LK294474           LK0      LK0A                   L
# ...              ...           ...       ...                 ...
# 2625  KFA115RK204079           LW1      LW1A                   L
# 2626  KFA115RK247921           LW1      LW1A                   L
# 2627  KFA110RK249849           LW1      LW1A                   L
# 2628  KFA111RK255210           LW1      LW1A                   L
# 2629  KFA115RK255243           LW1      LW1A                   L
#
# [1478 rows x 9 columns]

# %%
df_L_count = df_stock_L[["Bulan"]].copy()
df_L_count["count"] = 1.
df_L_count = df_L_count.groupby("Bulan").agg("count").reset_index()
df_L_count
# Out:
#         Bulan  count
# 0  2021-01-01      6
# 1  2021-02-01     38
# 2  2021-03-01     23
# 3  2021-04-01     41
# 4  2021-05-01     44
# 5  2021-06-01     46
# 6  2021-07-01     27
# 7  2021-08-01     31
# 8  2021-09-01     32
# 9  2021-10-01     36
# 10 2021-11-01     27
# 11 2021-12-01     13
# 12 2022-01-01      1
# 13 2022-02-01      1
# 14 2022-03-01     19
# 15 2022-04-01      8
# 16 2022-05-01      2
# 17 2022-06-01      7
# 18 2022-07-01      1
# 19 2022-10-01      1
# 20 2023-02-01      1
# 21 2023-03-01     16
# 22 2023-04-01     21
# 23 2023-05-01     14
# 24 2023-06-01     22
# 25 2023-07-01     22
# 26 2023-08-01     38
# 27 2023-09-01     27
# 28 2023-10-01     44
# 29 2023-11-01    101
# 30 2023-12-01    115
# 31 2024-01-01     20
# 32 2024-02-01     87
# 33 2024-03-01    107
# 34 2024-04-01     95
# 35 2024-05-01     95
# 36 2024-06-01    108
# 37 2024-07-01     69
# 38 2024-08-01     72

# %%
df_L_count["Bulan"] = pd.to_datetime(df_L_count["Bulan"])

# %%
fig, ax = plt.subplots(figsize=(8, 3))

ax.plot(df_L_count["Bulan"], df_L_count["count"], linestyle="-",
        marker=".")

formatter = mdates.DateFormatter("%b-%y")
# locator = mdates.YearLocator(base=2)
# locator = mdates.MonthLocator(bymonthday=1, bymonth=range(1, 13, 1))
locator = mdates.MonthLocator()
ax.xaxis.set_major_formatter(formatter)
ax.xaxis.set_major_locator(locator)

ax.grid("on")
ax.set_xlabel("Bulan")
ax.set_ylabel("Jumlah Stok")

ax.set_title("Varian L")

for j, label in enumerate(ax.get_xticklabels()):
  label.set_rotation(40)
  label.set_size(8)
  label.set_horizontalalignment('right')

plt.show(fig)

# %% [markdown]
# ### Varian M

# %%
df_stock_M = df_stock_initial[df_stock_initial["initial Varian Plus"] == "M"].copy()
df_stock_M
# Out:
#           Bulan Kode MD  Kode Dealer AHM  Kode Dealer SAP     No. Mesin  \
# 50   2021-02-01     R4Z              576       5200022542  JMC1E1479876
# 51   2021-02-01     R4Z              576       5200022542  JMC1E1481095
# 52   2021-02-01     R4Z              576       5200022542  JMC1E1481247
# 53   2021-02-01     R4Z              576       5200022542  JMD1E1692068
# 54   2021-02-01     R4Z              576       5200022542  JMD1E1697310
# ...         ...     ...              ...              ...           ...
# 2632 2024-08-01     R4Z             1858       5200022541  KFB1E1087704
# 2633 2024-08-01     R4Z             1858       5200022541  KFB1E1089792
# 2634 2024-08-01     R4Z             1858       5200022541  KFB1E1090542
# 2635 2024-08-01     R4Z             1858       5200022541  KFB2E1052137
# 2636 2024-08-01     R4Z             1858       5200022541  KFC1E1046262
#
#           No. Rangka Kode Tipe AHM Kode Tipe initial Varian Plus
# 50    JMC111RK480787           MC1      MC1A                   M
# 51    JMC116RK481384           MC1      MC1A                   M
# 52    JMC113RK482198           MC1      MC1A                   M
# 53    JMD118RK692463           MD1      MD1A                   M
# 54    JMD112RK697710           MD1      MD1A                   M
# ...              ...           ...       ...                 ...
# 2632  KFB119RK087757           MA0       MA0                   M
# 2633  KFB116RK089966           MA0       MA0                   M
# 2634  KFB118RK090522           MA0       MA0                   M
# 2635  KFB219RK052098           MB0       MB0                   M
# 2636  KFC116RK046038           MF0       MF0                   M
#
# [149 rows x 9 columns]

# %%
df_M_count = df_stock_M[["Bulan"]].copy()
df_M_count["count"] = 1.
df_M_count = df_M_count.groupby("Bulan").agg("count").reset_index()
df_M_count
# Out:
#         Bulan  count
# 0  2021-02-01     42
# 1  2022-12-01      1
# 2  2023-03-01      1
# 3  2023-08-01      1
# 4  2023-10-01      1
# 5  2023-11-01      2
# 6  2023-12-01      1
# 7  2024-02-01      3
# 8  2024-03-01      5
# 9  2024-04-01      5
# 10 2024-05-01      5
# 11 2024-06-01      7
# 12 2024-07-01      7
# 13 2024-08-01     68

# %%
df_M_count["Bulan"] = pd.to_datetime(df_M_count["Bulan"])

# %%
fig, ax = plt.subplots(figsize=(8, 3))

ax.plot(df_M_count["Bulan"], df_M_count["count"], linestyle="-",
        marker=".")

formatter = mdates.DateFormatter("%b-%y")
# locator = mdates.YearLocator(base=2)
# locator = mdates.MonthLocator(bymonthday=1, bymonth=range(1, 13, 1))
locator = mdates.MonthLocator()
ax.xaxis.set_major_formatter(formatter)
ax.xaxis.set_major_locator(locator)

ax.grid("on")
ax.set_xlabel("Bulan")
ax.set_ylabel("Jumlah Stok")

ax.set_title("Varian M")

for j, label in enumerate(ax.get_xticklabels()):
  label.set_rotation(40)
  label.set_size(8)
  label.set_horizontalalignment('right')

plt.show(fig)

# %% [markdown]
# ### Agregrasi Jumlah Pembeli

# %%
df_stock_count
# Out:
#   initial Varian Plus  count
# 0                   E    310
# 1                   G    105
# 2                   H    316
# 3                   J    279
# 4                   L   1478
# 5                   M    149

# %%
total_pembelian_varian_E_2021 = df_E_count["count"].sum()
print("Total pembelian unit varian E tahun 2021:", total_pembelian_varian_E_2021)
total_pembelian_varian_G_2021 = df_G_count["count"].sum()
print("Total pembelian unit varian G tahun 2021:", total_pembelian_varian_G_2021)
total_pembelian_varian_H_2021 = df_H_count["count"].sum()
print("Total pembelian unit varian H tahun 2021:", total_pembelian_varian_H_2021)
total_pembelian_varian_J_2021 = df_J_count["count"].sum()
print("Total pembelian unit varian J tahun 2021:", total_pembelian_varian_J_2021)
total_pembelian_varian_L_2021 = df_L_count["count"].sum()
print("Total pembelian unit varian L tahun 2021:", total_pembelian_varian_L_2021)
total_pembelian_varian_M_2021 = df_M_count["count"].sum()
print("Total pembelian unit varian M tahun 2021:", total_pembelian_varian_M_2021)
# Out:
# Total pembelian unit varian E tahun 2021: 310
# Total pembelian unit varian G tahun 2021: 105
# Total pembelian unit varian H tahun 2021: 316
# Total pembelian unit varian J tahun 2021: 279
# Total pembelian unit varian L tahun 2021: 1478
# Total pembelian unit varian M tahun 2021: 149
