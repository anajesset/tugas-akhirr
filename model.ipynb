# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd

# %%
plt.rcParams.update(plt.rcParamsDefault)
plt.rcParams.update({
  "font.size": 16,
  "grid.alpha": 0.25})

# %%
file_path = "./CDB THN 2021-2024.csv"
df_widget = pd.read_csv(file_path, parse_dates=[0])
df_widget
# Out:
#       Tgl. Mohon                    Nama                           Alamat  \
# 0     02/01/2021                  MULKAN                  JL AL MAKMUR I
# 1     02/01/2021     HANIE ZULFA NABIELA  JL MT HARYONO PERUM GRAND CITY
# 2     02/01/2021            HASANA PUTRI              JL LETJEND S PARMAN
# 3     02/01/2021             SUSARI HATI           JL MARSMA R ISWAHYUDI
# 4     02/01/2021            ROY KILAPONG                    JL MT HARYONO
# ...          ...                     ...                              ...
# 6852  31/08/2024               RUDI AMSA                  JL PADAT KARYA
# 6853  31/08/2024                 MARIATI            JL. TAMAN BUKIT SARI
# 6854  31/08/2024        JAMES HAROL SELA          JL. LETJEND. S. PARMAN
# 6855  31/08/2024  GOMGOM RAULI SIHOMBING                    PERUM BDS II
# 6856  31/08/2024       NURIANI PATANDEAN                JL BONTO BULAENG
#
#            Kelurahan           Kecamatan     Gender  Tgl. Lahir  \
# ...

# %%
df_widget.isnull().sum()
# Out:
# Tgl. Mohon       0
# Nama             0
# Alamat           0
# Kelurahan        0
# Kecamatan        0
# Gender         387
# Tgl. Lahir       0
# Pekerjaan      386
# Pengeluaran    387
# Pendidikan     387
# Varian Plus      0
# dtype: int64

# %% [markdown]
# Hal ini karena sebagian besar terdapat customer yang membeli sebagai perwakilan perusahaan bukan individu makanya data gender, pekerjaan, pengeluaran, dan pendidikan tidak diisi

# %%
df_widget['Gender'].fillna('Tidak Diisi', inplace=True)
df_widget['Pekerjaan'].fillna('Tidak Diisi', inplace=True)
df_widget['Pengeluaran'].fillna('Tidak Diisi', inplace=True)
df_widget['Pendidikan'].fillna('Tidak Diisi', inplace=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53444\3136577448.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_widget['Gender'].fillna('Tidak Diisi', inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_53444\3136577448.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df_widget.isnull().sum()
# Out:
# Tgl. Mohon     0
# Nama           0
# Alamat         0
# Kelurahan      0
# Kecamatan      0
# Gender         0
# Tgl. Lahir     0
# Pekerjaan      0
# Pengeluaran    0
# Pendidikan     0
# Varian Plus    0
# dtype: int64

# %%
df_widget
# Out:
#       Tgl. Mohon                    Nama                           Alamat  \
# 0     02/01/2021                  MULKAN                  JL AL MAKMUR I
# 1     02/01/2021     HANIE ZULFA NABIELA  JL MT HARYONO PERUM GRAND CITY
# 2     02/01/2021            HASANA PUTRI              JL LETJEND S PARMAN
# 3     02/01/2021             SUSARI HATI           JL MARSMA R ISWAHYUDI
# 4     02/01/2021            ROY KILAPONG                    JL MT HARYONO
# ...          ...                     ...                              ...
# 6852  31/08/2024               RUDI AMSA                  JL PADAT KARYA
# 6853  31/08/2024                 MARIATI            JL. TAMAN BUKIT SARI
# 6854  31/08/2024        JAMES HAROL SELA          JL. LETJEND. S. PARMAN
# 6855  31/08/2024  GOMGOM RAULI SIHOMBING                    PERUM BDS II
# 6856  31/08/2024       NURIANI PATANDEAN                JL BONTO BULAENG
#
#            Kelurahan           Kecamatan     Gender  Tgl. Lahir  \
# ...
