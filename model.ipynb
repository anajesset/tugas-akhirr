# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib as mpl
import pandas as pd
import datetime
import tensorflow as tf

from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.preprocessing import MinMaxScaler

# %%
plt.rcParams.update(plt.rcParamsDefault)
plt.rcParams.update({
  "font.size": 16,
  "grid.alpha": 0.25})

# %% [markdown]
# ### Function declarations

# %%
def plot_time_series(x, y, xlabel="Time", ylabel="Value", figsize=(10, 4), 
                     use_weekday_locator=False, use_year_locator=True, title=None, 
                     add_mark_at=None):
  fig, ax = plt.subplots(figsize=figsize)

  ax.plot(x, y)

  if use_weekday_locator:
    formatter = mdates.DateFormatter("%a")
    locator = mdates.DayLocator(interval=1)
  elif use_year_locator:
    formatter = mdates.DateFormatter("%Y-%b")
    # locator = mdates.YearLocator(base=1)
    # formatter = mdates.DateFormatter("%Y")
    locator = mdates.MonthLocator(bymonthday=1, bymonth=range(1, 13, 2))

  ax.xaxis.set_major_formatter(formatter)
  ax.xaxis.set_major_locator(locator)
  
  if add_mark_at:
    x_loc, cycle_length = add_mark_at
    ax.plot(x[x_loc::cycle_length], y[x_loc::cycle_length], linestyle="None",
      marker='o', markerfacecolor='w', markeredgewidth=2, 
      markeredgecolor="tab:blue")

  ax.grid("on")
  ax.set_xlabel(xlabel)
  ax.set_ylabel(ylabel)

  if title is not None:
    ax.set_title(title)

  if use_year_locator or use_weekday_locator:
    for j, label in enumerate(ax.get_xticklabels()):
      label.set_rotation(40)
      label.set_horizontalalignment('right')

  plt.show(fig)

# %%
def plot_time_series_data_window(
  x, y, xlabel="Time", ylabel="Value", figsize=(10, 4), 
  use_weekday_locator=False, use_year_locator=True, title=None, 
  add_mark_at=None, input_width=24, label_width=24):

  fig, ax = plt.subplots(figsize=figsize)

  num_of_rows = len(x)
  data_window_size = input_width + label_width
  num_of_data_window = num_of_rows // data_window_size
  input_color = "tab:blue" 
  label_color = "tab:orange" 
  
  for i in range(num_of_data_window):
    start_width_idx = i*data_window_size
    end_width_idx = i*data_window_size + input_width
    ax.plot(x.iloc[start_width_idx:end_width_idx], 
            y.iloc[start_width_idx:end_width_idx], color=input_color, 
            marker="s")
    
    start_label_idx = i*data_window_size + input_width
    end_label_idx = i*data_window_size + input_width + label_width
    ax.plot(x.iloc[start_label_idx:end_label_idx], 
            y.iloc[start_label_idx:end_label_idx], color=label_color, 
            marker="x")

  if use_weekday_locator:
    formatter = mdates.DateFormatter("%a")
    locator = mdates.DayLocator(interval=1)
  elif use_year_locator:
    formatter = mdates.DateFormatter("%Y-%b")
    # locator = mdates.YearLocator(base=1)
    # formatter = mdates.DateFormatter("%Y")
    locator = mdates.MonthLocator(bymonthday=1, bymonth=range(1, 13, 2))

  ax.xaxis.set_major_formatter(formatter)
  ax.xaxis.set_major_locator(locator)
  
  if add_mark_at:
    x_loc, cycle_length = add_mark_at
    ax.plot(x[x_loc::cycle_length], y[x_loc::cycle_length], linestyle="None",
      marker='o', markerfacecolor='w', markeredgewidth=2, 
      markeredgecolor="tab:blue")

  ax.grid("on")
  ax.set_xlabel(xlabel)
  ax.set_ylabel(ylabel)

  if title is not None:
    ax.set_title(title)

  if use_year_locator or use_weekday_locator:
    for j, label in enumerate(ax.get_xticklabels()):
      label.set_rotation(40)
      label.set_horizontalalignment('right')

  plt.show(fig)

# %% [markdown]
# ### Load

# %%
df_cdb = pd.read_csv("./data/CDB THN 2021-2024.csv", parse_dates=["Tgl. Mohon", "Tgl. Lahir"])
df_cdb
# Out:
# C:\Users\TEMP\AppData\Local\Temp\ipykernel_10200\207034497.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df_cdb = pd.read_csv("./data/CDB THN 2021-2024.csv", parse_dates=["Tgl. Mohon", "Tgl. Lahir"])
#       Tgl. Mohon                    Nama                           Alamat  \
# 0     02/01/2021                  MULKAN                  JL AL MAKMUR I
# 1     02/01/2021     HANIE ZULFA NABIELA  JL MT HARYONO PERUM GRAND CITY
# 2     02/01/2021            HASANA PUTRI              JL LETJEND S PARMAN
# 3     02/01/2021             SUSARI HATI           JL MARSMA R ISWAHYUDI
# 4     02/01/2021            ROY KILAPONG                    JL MT HARYONO
# ...          ...                     ...                              ...
# 6852  31/08/2024               RUDI AMSA                  JL PADAT KARYA
# 6853  31/08/2024                 MARIATI            JL. TAMAN BUKIT SARI
# 6854  31/08/2024        JAMES HAROL SELA          JL. LETJEND. S. PARMAN
# 6855  31/08/2024  GOMGOM RAULI SIHOMBING                    PERUM BDS II
# 6856  31/08/2024       NURIANI PATANDEAN                JL BONTO BULAENG
#
#            Kelurahan           Kecamatan     Gender Tgl. Lahir  \
# 0              DAMAI     BALIKPAPAN KOTA  LAKI-LAKI 1996-08-18
# 1        GRAHA INDAH    BALIKPAPAN UTARA  PEREMPUAN 2003-04-14
# 2        SUMBER REJO   BALIKPAPAN TENGAH  PEREMPUAN 1997-02-13
# 3       SUNGAINANGKA  BALIKPAPAN SELATAN  PEREMPUAN 1982-11-16
# 4      DAMAI BAHAGIA  BALIKPAPAN SELATAN  LAKI-LAKI 1976-01-17
# ...              ...                 ...        ...        ...
# 6852         MANGGAR    BALIKPAPAN TIMUR  LAKI-LAKI 2004-11-06
# 6853     GRAHA INDAH    BALIKPAPAN UTARA  PEREMPUAN 1978-03-21
# 6854  GUNUNGSARI ULU   BALIKPAPAN TENGAH  LAKI-LAKI 1961-01-19
# 6855    SUNGAINANGKA  BALIKPAPAN SELATAN  PEREMPUAN 1980-04-30
# 6856     SUMBER REJO   BALIKPAPAN TENGAH  PEREMPUAN 1993-04-08
#
#                      Pekerjaan                          Pengeluaran  \
# 0              Wiraswasta-Jasa  Rp. 1.750.001,- s/d Rp. 2.500.000,-
# 1          Pegawai Swasta-Jasa                      < Rp. 900.000,-
# 2     Pegawai Swasta-Pertanian    Rp. 900.001,- s/d Rp. 1.250.000,-
# 3      Pegawai Swasta-Industri  Rp. 4.000.001,- s/d Rp. 6.000.000,-
# 4          Pegawai Swasta-Jasa  Rp. 2.500.001,- s/d Rp. 4.000.000,-
# ...                        ...                                  ...
# 6852       Pegawai Swasta-Jasa    Rp. 900.001,- s/d Rp. 1.250.000,-
# 6853       Pegawai Swasta-Jasa  Rp. 1.750.001,- s/d Rp. 2.500.000,-
# 6854       Pegawai Swasta-Jasa  Rp. 1.750.001,- s/d Rp. 2.500.000,-
# 6855          IBU RUMAH TANGGA  Rp. 1.250.001,- s/d Rp. 1.750.000,-
# 6856          IBU RUMAH TANGGA    Rp. 900.001,- s/d Rp. 1.250.000,-
#
#            Pendidikan Varian Plus
# 0            SLTP/SMP         LD0
# 1     AKADEMI/DIPLOMA         LP0
# 2             SARJANA         LPA
# 3            SLTA/SMU         LP0
# 4            SLTA/SMU         LPA
# ...               ...         ...
# 6852         SLTA/SMU         MM0
# 6853         SLTA/SMU         MM0
# 6854          SARJANA         LP3
# 6855         SLTA/SMU         ML0
# 6856         SLTA/SMU         LW1
#
# [6857 rows x 11 columns]

# %%
df_cdb_with_initial = df_cdb.copy()

df_cdb_with_initial["initial Varian Plus"] = df_cdb_with_initial["Varian Plus"].apply(lambda x: x[0])

def tipe_customer(row):
    if row[["Gender", "Tgl. Lahir", "Pekerjaan", "Pengeluaran", "Pendidikan"]].isnull().any():
        return "INSTANSI LUAR"
    else:
        return "INDIVIDU"

df_cdb_with_initial["Tipe Pembeli"] = df_cdb_with_initial.apply(tipe_customer, axis=1)

df_cdb_with_initial["Umur"] = (pd.to_datetime("today") - df_cdb_with_initial["Tgl. Lahir"]).dt.days // 365

# Cek hasil
df_cdb_with_initial
# Out:
#       Tgl. Mohon                    Nama                           Alamat  \
# 0     02/01/2021                  MULKAN                  JL AL MAKMUR I
# 1     02/01/2021     HANIE ZULFA NABIELA  JL MT HARYONO PERUM GRAND CITY
# 2     02/01/2021            HASANA PUTRI              JL LETJEND S PARMAN
# 3     02/01/2021             SUSARI HATI           JL MARSMA R ISWAHYUDI
# 4     02/01/2021            ROY KILAPONG                    JL MT HARYONO
# ...          ...                     ...                              ...
# 6852  31/08/2024               RUDI AMSA                  JL PADAT KARYA
# 6853  31/08/2024                 MARIATI            JL. TAMAN BUKIT SARI
# 6854  31/08/2024        JAMES HAROL SELA          JL. LETJEND. S. PARMAN
# 6855  31/08/2024  GOMGOM RAULI SIHOMBING                    PERUM BDS II
# 6856  31/08/2024       NURIANI PATANDEAN                JL BONTO BULAENG
#
#            Kelurahan           Kecamatan     Gender Tgl. Lahir  \
# 0              DAMAI     BALIKPAPAN KOTA  LAKI-LAKI 1996-08-18
# 1        GRAHA INDAH    BALIKPAPAN UTARA  PEREMPUAN 2003-04-14
# 2        SUMBER REJO   BALIKPAPAN TENGAH  PEREMPUAN 1997-02-13
# 3       SUNGAINANGKA  BALIKPAPAN SELATAN  PEREMPUAN 1982-11-16
# 4      DAMAI BAHAGIA  BALIKPAPAN SELATAN  LAKI-LAKI 1976-01-17
# ...              ...                 ...        ...        ...
# 6852         MANGGAR    BALIKPAPAN TIMUR  LAKI-LAKI 2004-11-06
# 6853     GRAHA INDAH    BALIKPAPAN UTARA  PEREMPUAN 1978-03-21
# 6854  GUNUNGSARI ULU   BALIKPAPAN TENGAH  LAKI-LAKI 1961-01-19
# 6855    SUNGAINANGKA  BALIKPAPAN SELATAN  PEREMPUAN 1980-04-30
# 6856     SUMBER REJO   BALIKPAPAN TENGAH  PEREMPUAN 1993-04-08
#
#                      Pekerjaan                          Pengeluaran  \
# 0              Wiraswasta-Jasa  Rp. 1.750.001,- s/d Rp. 2.500.000,-
# 1          Pegawai Swasta-Jasa                      < Rp. 900.000,-
# 2     Pegawai Swasta-Pertanian    Rp. 900.001,- s/d Rp. 1.250.000,-
# 3      Pegawai Swasta-Industri  Rp. 4.000.001,- s/d Rp. 6.000.000,-
# 4          Pegawai Swasta-Jasa  Rp. 2.500.001,- s/d Rp. 4.000.000,-
# ...                        ...                                  ...
# 6852       Pegawai Swasta-Jasa    Rp. 900.001,- s/d Rp. 1.250.000,-
# 6853       Pegawai Swasta-Jasa  Rp. 1.750.001,- s/d Rp. 2.500.000,-
# 6854       Pegawai Swasta-Jasa  Rp. 1.750.001,- s/d Rp. 2.500.000,-
# 6855          IBU RUMAH TANGGA  Rp. 1.250.001,- s/d Rp. 1.750.000,-
# 6856          IBU RUMAH TANGGA    Rp. 900.001,- s/d Rp. 1.250.000,-
#
#            Pendidikan Varian Plus initial Varian Plus Tipe Pembeli  Umur
# 0            SLTP/SMP         LD0                   L     INDIVIDU    28
# 1     AKADEMI/DIPLOMA         LP0                   L     INDIVIDU    21
# 2             SARJANA         LPA                   L     INDIVIDU    28
# 3            SLTA/SMU         LP0                   L     INDIVIDU    42
# 4            SLTA/SMU         LPA                   L     INDIVIDU    49
# ...               ...         ...                 ...          ...   ...
# 6852         SLTA/SMU         MM0                   M     INDIVIDU    20
# 6853         SLTA/SMU         MM0                   M     INDIVIDU    46
# 6854          SARJANA         LP3                   L     INDIVIDU    64
# 6855         SLTA/SMU         ML0                   M     INDIVIDU    44
# 6856         SLTA/SMU         LW1                   L     INDIVIDU    31
#
# [6857 rows x 14 columns]

# %%
dataset_section = ['train', 'val', 'test']
dataset = {}
for section in dataset_section:
  dataset[section+"_scale_df"] = df_cdb_with_initial

dataset["train_scale_df"]
# Out:
#       Tgl. Mohon                    Nama                           Alamat  \
# 0     02/01/2021                  MULKAN                  JL AL MAKMUR I
# 1     02/01/2021     HANIE ZULFA NABIELA  JL MT HARYONO PERUM GRAND CITY
# 2     02/01/2021            HASANA PUTRI              JL LETJEND S PARMAN
# 3     02/01/2021             SUSARI HATI           JL MARSMA R ISWAHYUDI
# 4     02/01/2021            ROY KILAPONG                    JL MT HARYONO
# ...          ...                     ...                              ...
# 6852  31/08/2024               RUDI AMSA                  JL PADAT KARYA
# 6853  31/08/2024                 MARIATI            JL. TAMAN BUKIT SARI
# 6854  31/08/2024        JAMES HAROL SELA          JL. LETJEND. S. PARMAN
# 6855  31/08/2024  GOMGOM RAULI SIHOMBING                    PERUM BDS II
# 6856  31/08/2024       NURIANI PATANDEAN                JL BONTO BULAENG
#
#            Kelurahan           Kecamatan     Gender Tgl. Lahir  \
# 0              DAMAI     BALIKPAPAN KOTA  LAKI-LAKI 1996-08-18
# 1        GRAHA INDAH    BALIKPAPAN UTARA  PEREMPUAN 2003-04-14
# 2        SUMBER REJO   BALIKPAPAN TENGAH  PEREMPUAN 1997-02-13
# 3       SUNGAINANGKA  BALIKPAPAN SELATAN  PEREMPUAN 1982-11-16
# 4      DAMAI BAHAGIA  BALIKPAPAN SELATAN  LAKI-LAKI 1976-01-17
# ...              ...                 ...        ...        ...
# 6852         MANGGAR    BALIKPAPAN TIMUR  LAKI-LAKI 2004-11-06
# 6853     GRAHA INDAH    BALIKPAPAN UTARA  PEREMPUAN 1978-03-21
# 6854  GUNUNGSARI ULU   BALIKPAPAN TENGAH  LAKI-LAKI 1961-01-19
# 6855    SUNGAINANGKA  BALIKPAPAN SELATAN  PEREMPUAN 1980-04-30
# 6856     SUMBER REJO   BALIKPAPAN TENGAH  PEREMPUAN 1993-04-08
#
#                      Pekerjaan                          Pengeluaran  \
# 0              Wiraswasta-Jasa  Rp. 1.750.001,- s/d Rp. 2.500.000,-
# 1          Pegawai Swasta-Jasa                      < Rp. 900.000,-
# 2     Pegawai Swasta-Pertanian    Rp. 900.001,- s/d Rp. 1.250.000,-
# 3      Pegawai Swasta-Industri  Rp. 4.000.001,- s/d Rp. 6.000.000,-
# 4          Pegawai Swasta-Jasa  Rp. 2.500.001,- s/d Rp. 4.000.000,-
# ...                        ...                                  ...
# 6852       Pegawai Swasta-Jasa    Rp. 900.001,- s/d Rp. 1.250.000,-
# 6853       Pegawai Swasta-Jasa  Rp. 1.750.001,- s/d Rp. 2.500.000,-
# 6854       Pegawai Swasta-Jasa  Rp. 1.750.001,- s/d Rp. 2.500.000,-
# 6855          IBU RUMAH TANGGA  Rp. 1.250.001,- s/d Rp. 1.750.000,-
# 6856          IBU RUMAH TANGGA    Rp. 900.001,- s/d Rp. 1.250.000,-
#
#            Pendidikan Varian Plus initial Varian Plus Tipe Pembeli  Umur
# 0            SLTP/SMP         LD0                   L     INDIVIDU    28
# 1     AKADEMI/DIPLOMA         LP0                   L     INDIVIDU    21
# 2             SARJANA         LPA                   L     INDIVIDU    28
# 3            SLTA/SMU         LP0                   L     INDIVIDU    42
# 4            SLTA/SMU         LPA                   L     INDIVIDU    49
# ...               ...         ...                 ...          ...   ...
# 6852         SLTA/SMU         MM0                   M     INDIVIDU    20
# 6853         SLTA/SMU         MM0                   M     INDIVIDU    46
# 6854          SARJANA         LP3                   L     INDIVIDU    64
# 6855         SLTA/SMU         ML0                   M     INDIVIDU    44
# 6856         SLTA/SMU         LW1                   L     INDIVIDU    31
#
# [6857 rows x 14 columns]

# %% [markdown]
# Encoding

# %%
df_cdb_enc = dataset["train_scale_df"].copy()

categorical_features = ["Kelurahan", "Kecamatan", "Gender", "Pekerjaan", "Pengeluaran", "Pendidikan", "Varian Plus", "initial Varian Plus", "Tipe Pembeli"]

label_encoders = {}
for col in categorical_features:
    le = LabelEncoder()
    df_cdb_enc[col] = le.fit_transform(df_cdb_enc[col])
    label_encoders[col] = le

df_cdb_enc
# Out:
#       Tgl. Mohon                    Nama                           Alamat  \
# 0     02/01/2021                  MULKAN                  JL AL MAKMUR I
# 1     02/01/2021     HANIE ZULFA NABIELA  JL MT HARYONO PERUM GRAND CITY
# 2     02/01/2021            HASANA PUTRI              JL LETJEND S PARMAN
# 3     02/01/2021             SUSARI HATI           JL MARSMA R ISWAHYUDI
# 4     02/01/2021            ROY KILAPONG                    JL MT HARYONO
# ...          ...                     ...                              ...
# 6852  31/08/2024               RUDI AMSA                  JL PADAT KARYA
# 6853  31/08/2024                 MARIATI            JL. TAMAN BUKIT SARI
# 6854  31/08/2024        JAMES HAROL SELA          JL. LETJEND. S. PARMAN
# 6855  31/08/2024  GOMGOM RAULI SIHOMBING                    PERUM BDS II
# 6856  31/08/2024       NURIANI PATANDEAN                JL BONTO BULAENG
#
#       Kelurahan  Kecamatan  Gender Tgl. Lahir  Pekerjaan  Pengeluaran  \
# 0            41          3       0 1996-08-18         18            3
# 1            51          7       1 2003-04-14         10            0
# 2           204          5       1 1997-02-13         14            6
# 3           212          4       1 1982-11-16          9            5
# 4            43          4       0 1976-01-17         10            4
# ...         ...        ...     ...        ...        ...          ...
# 6852        116          6       0 2004-11-06         10            6
# 6853         51          7       1 1978-03-21         10            3
# 6854         71          5       0 1961-01-19         10            3
# 6855        212          4       1 1980-04-30          2            2
# 6856        204          5       1 1993-04-08          2            6
#
#       Pendidikan  Varian Plus  initial Varian Plus  Tipe Pembeli  Umur
# 0              5           53                    4             0    28
# 1              0           79                    4             0    21
# 2              2           83                    4             0    28
# 3              4           79                    4             0    42
# 4              4           83                    4             0    49
# ...          ...          ...                  ...           ...   ...
# 6852           4          114                    5             0    20
# 6853           4          114                    5             0    46
# 6854           2           82                    4             0    64
# 6855           4          113                    5             0    44
# 6856           4           96                    4             0    31
#
# [6857 rows x 14 columns]

# %% [markdown]
# ### Data Pre-processing
