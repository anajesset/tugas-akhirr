# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load Data

# %%
file_path = "./data/CDB THN 2021-2024.csv"
df_cdb = pd.read_csv(file_path)
df_cdb["Tgl. Mohon"] = pd.to_datetime(df_cdb["Tgl. Mohon"], format="%d/%m/%Y")
df_cdb["Tgl. Lahir"] = pd.to_datetime(df_cdb["Tgl. Lahir"], format="%d/%m/%Y")
df_cdb
# Out:
#      Tgl. Mohon                    Nama                           Alamat  \
# 0    2021-01-02                  MULKAN                  JL AL MAKMUR I
# 1    2021-01-02     HANIE ZULFA NABIELA  JL MT HARYONO PERUM GRAND CITY
# 2    2021-01-02            HASANA PUTRI              JL LETJEND S PARMAN
# 3    2021-01-02             SUSARI HATI           JL MARSMA R ISWAHYUDI
# 4    2021-01-02            ROY KILAPONG                    JL MT HARYONO
# ...         ...                     ...                              ...
# 6852 2024-08-31               RUDI AMSA                  JL PADAT KARYA
# 6853 2024-08-31                 MARIATI            JL. TAMAN BUKIT SARI
# 6854 2024-08-31        JAMES HAROL SELA          JL. LETJEND. S. PARMAN
# 6855 2024-08-31  GOMGOM RAULI SIHOMBING                    PERUM BDS II
# 6856 2024-08-31       NURIANI PATANDEAN                JL BONTO BULAENG
#
#            Kelurahan           Kecamatan     Gender Tgl. Lahir  \
# ...

# %%
df_cdb_with_initial = df_cdb.copy()
df_cdb_with_initial["initial Varian Plus"] = df_cdb_with_initial["Varian Plus"].apply(lambda x: x[0])
df_cdb_with_initial
# Out:
#      Tgl. Mohon                    Nama                           Alamat  \
# 0    2021-01-02                  MULKAN                  JL AL MAKMUR I
# 1    2021-01-02     HANIE ZULFA NABIELA  JL MT HARYONO PERUM GRAND CITY
# 2    2021-01-02            HASANA PUTRI              JL LETJEND S PARMAN
# 3    2021-01-02             SUSARI HATI           JL MARSMA R ISWAHYUDI
# 4    2021-01-02            ROY KILAPONG                    JL MT HARYONO
# ...         ...                     ...                              ...
# 6852 2024-08-31               RUDI AMSA                  JL PADAT KARYA
# 6853 2024-08-31                 MARIATI            JL. TAMAN BUKIT SARI
# 6854 2024-08-31        JAMES HAROL SELA          JL. LETJEND. S. PARMAN
# 6855 2024-08-31  GOMGOM RAULI SIHOMBING                    PERUM BDS II
# 6856 2024-08-31       NURIANI PATANDEAN                JL BONTO BULAENG
#
#            Kelurahan           Kecamatan     Gender Tgl. Lahir  \
# ...

# %%
df_cdb_with_tipe = df_cdb_with_initial.copy()
def tipe_customer(row):
    if row[["Gender", "Tgl. Lahir", "Pekerjaan", "Pengeluaran", "Pendidikan"]].isnull().any():
        return "INSTANSI LUAR"
    else:
        return "INDIVIDU"

df_cdb_with_tipe["Tipe Pembeli"] = df_cdb_with_tipe.apply(tipe_customer, axis=1)
df_cdb_with_tipe["Umur"] = (pd.to_datetime("today") - df_cdb_with_tipe["Tgl. Lahir"]).dt.days // 365

df_cdb_with_tipe
# Out:
#      Tgl. Mohon                    Nama                           Alamat  \
# 0    2021-01-02                  MULKAN                  JL AL MAKMUR I
# 1    2021-01-02     HANIE ZULFA NABIELA  JL MT HARYONO PERUM GRAND CITY
# 2    2021-01-02            HASANA PUTRI              JL LETJEND S PARMAN
# 3    2021-01-02             SUSARI HATI           JL MARSMA R ISWAHYUDI
# 4    2021-01-02            ROY KILAPONG                    JL MT HARYONO
# ...         ...                     ...                              ...
# 6852 2024-08-31               RUDI AMSA                  JL PADAT KARYA
# 6853 2024-08-31                 MARIATI            JL. TAMAN BUKIT SARI
# 6854 2024-08-31        JAMES HAROL SELA          JL. LETJEND. S. PARMAN
# 6855 2024-08-31  GOMGOM RAULI SIHOMBING                    PERUM BDS II
# 6856 2024-08-31       NURIANI PATANDEAN                JL BONTO BULAENG
#
#            Kelurahan           Kecamatan     Gender Tgl. Lahir  \
# ...

# %%
df_H = df_cdb_with_tipe[df_cdb_with_tipe["initial Varian Plus"] == "H"].copy()
df_H
# Out:
#      Tgl. Mohon                       Nama                             Alamat  \
# 12   2021-01-05              JULI HARJANTO                           JL BLORA
# 13   2021-01-06  DHINA R. AGUSTIANA DA, SE              JL MASJID AR RAUDAH I
# 24   2021-01-07       AHMAD HABIBI HARAHAP                  JL DAKSA TIMUR I
# 31   2021-01-07      GALIH PUTRO WICAKSONO  JL JEND SUDIRMAN ASPOL STAL KUDA
# 37   2021-01-09          VELIANA FEBRIANTI                 JL GUNUNG GEMBIRA
# ...         ...                        ...                                ...
# 5956 2024-04-06            ERNIE DIANA NUR                     JL. SIDOMULYO
# 6330 2024-06-06                       ERNI    JL. WOLTET MONGINSIDI GG. MACAN
# 6351 2024-06-10                   ZULFIKAR                      JL TELINDUNG
# 6501 2024-07-08                      JOSUA               JL JENDRAL SUDIRMAN
# 6674 2024-08-05            INOSENSIUS LUSI          JL KAKATUA 2 PERUM BDS 2
#
# ...

# %%
df_H_week = df_H.copy()
df_H_week['Minggu'] = df_H['Tgl. Mohon'].dt.to_period('W').apply(lambda r: r.start_time)
df_H_week
# Out:
#      Tgl. Mohon                       Nama                             Alamat  \
# 12   2021-01-05              JULI HARJANTO                           JL BLORA
# 13   2021-01-06  DHINA R. AGUSTIANA DA, SE              JL MASJID AR RAUDAH I
# 24   2021-01-07       AHMAD HABIBI HARAHAP                  JL DAKSA TIMUR I
# 31   2021-01-07      GALIH PUTRO WICAKSONO  JL JEND SUDIRMAN ASPOL STAL KUDA
# 37   2021-01-09          VELIANA FEBRIANTI                 JL GUNUNG GEMBIRA
# ...         ...                        ...                                ...
# 5956 2024-04-06            ERNIE DIANA NUR                     JL. SIDOMULYO
# 6330 2024-06-06                       ERNI    JL. WOLTET MONGINSIDI GG. MACAN
# 6351 2024-06-10                   ZULFIKAR                      JL TELINDUNG
# 6501 2024-07-08                      JOSUA               JL JENDRAL SUDIRMAN
# 6674 2024-08-05            INOSENSIUS LUSI          JL KAKATUA 2 PERUM BDS 2
#
# ...

# %%
df_H_week['Minggu'] = df_H_week['Tgl. Mohon'].dt.to_period('W').apply(lambda r: r.start_time)

df_weekly = df_H_week.groupby(['Minggu', 'Kecamatan', 'Kelurahan']).agg({
    'Nama': 'count',
    'Umur': 'mean',
    'Pengeluaran_num': 'mean',
    'Gender': lambda x: (x == 'PEREMPUAN').mean()
}).reset_index()

df_weekly.rename(columns={'Nama': 'Jumlah_Penjualan', 'Gender': 'Persen_Perempuan'}, inplace=True)

# %%
print("Pearson:")
print(df_weekly[['Jumlah_Penjualan', 'Umur', 'Pengeluaran_num', 'Persen_Perempuan']].corr(method='pearson'))

print("\nSpearman:")
print(df_weekly[['Jumlah_Penjualan', 'Umur', 'Pengeluaran_num', 'Persen_Perempuan']].corr(method='spearman'))
# Out:
# Pearson:
#                   Jumlah_Penjualan      Umur  Pengeluaran_num  \
# Jumlah_Penjualan          1.000000 -0.027541         0.008052
# Umur                     -0.027541  1.000000         0.202682
# Pengeluaran_num           0.008052  0.202682         1.000000
# Persen_Perempuan          0.016537  0.013661         0.010965
#
#                   Persen_Perempuan
# Jumlah_Penjualan          0.016537
# Umur                      0.013661
# Pengeluaran_num           0.010965
# Persen_Perempuan          1.000000
#
# Spearman:
#                   Jumlah_Penjualan      Umur  Pengeluaran_num  \
# Jumlah_Penjualan          1.000000 -0.016139         0.062265
# Umur                     -0.016139  1.000000         0.270098
# Pengeluaran_num           0.062265  0.270098         1.000000
# Persen_Perempuan          0.036452  0.049658         0.011675
#
#                   Persen_Perempuan
# Jumlah_Penjualan          0.036452
# Umur                      0.049658
# ...

# %%
from scipy.stats import chi2_contingency

def chi_square_test(data, cat_column):
    table = pd.crosstab(data[cat_column], data['Jumlah_Penjualan'])
    chi2, p, dof, ex = chi2_contingency(table)
    return p

print("Chi-Square (Kecamatan):", chi_square_test(df_H_week, 'Kecamatan'))
print("Chi-Square (Kelurahan):", chi_square_test(df_H_week, 'Kelurahan'))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\ProgramData\miniconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Jumlah_Penjualan'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 8
#       5     chi2, p, dof, ex = chi2_contingency(table)
# ...

# %%
df_model = pd.get_dummies(df_H_weekly, columns=['Kecamatan', 'Kelurahan'])
df_model = df_model.sort_values('Minggu')

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()

X_scaled = scaler_x.fit_transform(features)
y_scaled = scaler_y.fit_transform(target.reshape(-1, 1))

# Buat sequence
def create_sequences(X, y, seq_length):
    Xs, ys = [], []
    for i in range(seq_length, len(X)):
        Xs.append(X[i-seq_length:i])
        ys.append(y[i])
    return np.array(Xs), np.array(ys)

seq_length = 5
X_seq, y_seq = create_sequences(X_scaled, y_scaled, seq_length)
